# %% [markdown]
# # 🙌🏻Welcome to Professor Heewon Kim’s Machine Learning Class – Week 2 Assignment
# This code was generated for the Machine Learning class at Soongsil University (Realitylab).

# %% [markdown]
# ## The Gaussian Distribution
#
# 확률변수 $Z$가 따르는 가우시안/정규분포의 확률밀도함수는 다음과 같다.
# $$ p(z) = \frac{1}{\sqrt{2\pi}} e^{-z^2 / 2}. $$
#
# 이는 모든 실수 값 $z$, 즉 $-\infty$ 부터 $\infty$ 까지 정의된다.
#
# 분포는 다음과 같은 형태를 가진다.

# %%
# !pip install -q symbulate
from symbulate import *

# %%
Normal().plot()

# %% [markdown]
# ## The (General) Normal Distribution
#
# 표준 정규분포는 평균이 0이고 분산이 1인 분포이다. 일반적으로 우리는 아래의 두 항목을 할 수 있다.
# - scale the bell shape to be as wide as we want,
# - shift the bell shape to be centered wherever we want.
#
# 만약 $Z$ 가 정규 분포(standard normal) 라면,
# $$ X = \mu + \sigma Z $$
# 는 $\text{Normal}(\mu, \sigma)$ 를 따른다.
#
# 여기에서 parameter $\mu$ 는 expected value이고, parameter $\sigma$ 는 표준 편차(standard deviation)이다. (따라서 $\sigma^2$ 는 variance이다.)

# %% [markdown]
# ## Assignment 1
# 여러 개의 정규분포를 생성하여 비교하시오.
#
# 각 분포는 평균과 표준편차가 다르며, 이를 통해 **μ**이 분포의 중심 위치를 어떻게 바꾸는지, 그리고 **σ**가 분포의 폭과 모양을 어떻게 변화시키는지 확인할 수 있습니다.
#
# 다음 분포들을 한 그래프에 그려 서로 비교하라. 각 분포는 다른 색으로 표시하고 범례(legend)를 추가하시오.
#
# - 평균 = 1, 표준편차 = 0.25
# - 평균 = 1, 표준편차 = 0.5
# - 평균 = 1, 표준편차 = 0.75
# - 평균 = 3, 표준편차 = 0.25
# - 평균 = 3, 표준편차 = 0.5
# - 평균 = 3, 표준편차 = 0.75

# %%
''' Assignment 1 '''
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

x = np.linspace(-1, 5, 500)

params = [
    (1, 0.25),
    (1, 0.5),
    (1, 0.75),
    (3, 0.25),
    (3, 0.5),
    (3, 0.75)
]

plt.figure(figsize=(10, 6))
for mu, sigma in params:
    plt.plot(x, norm.pdf(x, mu, sigma), label=f'μ={mu}, σ={sigma}')

plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# # Probability
#
# 확률을 계산하기 위해서는 해당 구간에 대해 확률밀도함수(p.d.f.)를 적분한다. 예를 들어,
#
# $$ P(Z \leq 1) = \int_{-\infty}^1 \frac{1}{\sqrt{2\pi}} e^{-z^2 / 2}\,dz. $$
#
# 우리가 이전에 공부한 다른 연속분포와 달리, 확률밀도함수 $p(z)$는 초등적(초등함수 형태의) 부정적분을 가지지 않는다. 이는 미적분에서 배운 기법만으로는 이 적분을 종이에 직접 계산할 수 없음을 의미한다. 따라서 수치적으로 계산해야 한다. 다행히, Symbulate을 사용하면 이를 쉽게 계산할 수 있다.
#
# 예를 들어, $P(Z \leq 1)$ 은 단순히 누적분포함수(c.d.f.)를 $1$ 에서 평가한 값이다. 표준 정규분포의 누적분포함수는 흔히 $\Phi(z)$로 표기된다. 따라서 우리는 $\Phi(1)$을 계산해야 한다.

# %%
Normal().cdf(1)
# Out:
# 0.8413447460685429

# %% [markdown]
# ## Assignment 2:
#
# 표준 정규분포 $Z∼N(0,1)$ 에 대하여, 확률 $P(−2<Z<2)$ 를 계산하시오.
#
# 힌트: 표준 정규분포의 누적분포함수(CDF, $Φ(z)$ )를 이용하여 구할 수 있다.
#
# **파이썬의 Normal().cdf 함수를 사용하여 작성하시오.**
#
# **그 외의 함수를 활용하면 0점 처리하겠습니다**

# %%
''' Assignment 2'''
# P(-2 < Z < 2) = P(Z < 2) - P(Z < -2)

Normal().cdf(2) - Normal().cdf(-2)
# Out:
# 0.9544997361036416

# %% [markdown]
# # Monte Carlo Approximation
#
# ## Example 1: Coin Flip Example
#
# 공정한 동전에서 앞면이 나올 확률은 $1/2$이다. 몬테카를로 방법을 사용하여 동전 던지기를 5000번 반복적으로 시뮬레이션하여, 앞면이나 뒷면이 나올 확률이 항상 $1/2$임을 확인한다.
#
# <p align="center">
#   <img src="https://raw.githubusercontent.com/shiernee/Advanced_ML/main/Week2/CoinFlip.png" width="450"/>
# </p>

# %%
import random
import numpy as np
import matplotlib.pyplot as plt
# ================== import requirement library ================== #

# coin flip function:
# 0 --> Head
# 1 --> Tail

def coin_flip():
  return random.randint(0, 1)

# check the output of coin_flip
for i in range(10):
  print('iteration' + str(i) + '--> ' + str(coin_flip()))

# Monte Carlo Simulation
list1= []

def monte_carlo(n):
  results = 0
  plt.axhline(y=0.5, color='r', linestyle='-')

  for i in range(n):
    flip_result = coin_flip()
    results = results + flip_result

    # calculate probabibility valuue
    prob_value = results / (i+1)

    # append probability to list1
    list1.append(prob_value)

    # plot results    
    plt.xlabel('iteration')
    plt.ylabel('probability')
    plt.plot(list1)

  return results / n
# Out:
# iteration0--> 0
# iteration1--> 0
# iteration2--> 0
# iteration3--> 0
# iteration4--> 0
# iteration5--> 0
# iteration6--> 1
# iteration7--> 1
# iteration8--> 1
# iteration9--> 0

# %%
# call monte carlo functioin
answer = monte_carlo(10000)
print('final value of probability: ', answer)
# Out:
# final value of probability:  0.4974

# %% [markdown]
# # Example 2: Estimating Pi from Circle and Square
#
# $\pi$ 값을 추정하기 위해, 우리는 원과 정사각형의 면적을 사용할 수 있다.
#
# $$ \frac{Area \ Circle}{Area \ Square} = \frac{\pi*r^2}{2r * 2r}  $$
# $$ \frac{Area \ Circle}{Area \ Square} = \frac{\pi}{4}  $$
#
# 따라서 $\pi$값은 다음 공식을 사용하여 추정할 수 있다.
# $$ \pi = 4* \frac{Area \ Circle}{Area \ Square} $$
#
# <p align="center">
# <img src="https://raw.githubusercontent.com/shiernee/Advanced_ML/main/Week2/EstimatePiFromCircleSquare.png" width="350">
# </p>
#
# $$ r = 0.5 \text{라고\ 가정하면,} $$
#
# $$ \text{length\_of\_field} = 2r = 1.0 $$

# %%
import turtle
from random import random 
import matplotlib.pyplot as plt
import math
# ================== import requirement library ================== #

# simulate raindrop 
# return x and y coordinates of raindrop

def rain_drop(length_of_field=1):
    """
    Simulate a random rain drop
    """
    return [(.5 - random()) * length_of_field, (.5 - random()) * length_of_field]

# check if raindrop fall in circle by using circle formula 

def is_point_in_circle(point, length_of_field=1):
    """
    Return True if point is in inscribed circle
    Use circle formula --> x^2 + y^2 <= r^2
    """
    return (point[0]) ** 2 + (point[1]) ** 2 <= (length_of_field / 2) ** 2

def plot_rain_drops(drops_in_circle, drops_out_of_circle, length_of_field=1, format='pdf'):
    """ Function to draw rain drops """
    number_of_drops_in_circle = len(drops_in_circle)
    number_of_drops_out_of_circle = len(drops_out_of_circle)
    number_of_drops = number_of_drops_in_circle + number_of_drops_out_of_circle
    plt.figure()
    plt.xlim(-length_of_field / 2, length_of_field / 2)
    plt.ylim(-length_of_field / 2, length_of_field / 2)
    plt.scatter([e[0] for e in drops_in_circle], [e[1] for e in drops_in_circle], color='blue', label="Drops in circle")
    plt.scatter([e[0] for e in drops_out_of_circle], [e[1] for e in drops_out_of_circle], color='black', label="Drops out of circle")
    plt.legend(loc="center")
    plt.title("%s drops: %s landed in circle, estimating $\pi$ as %.4f." % (number_of_drops, number_of_drops_in_circle, 4 * number_of_drops_in_circle / number_of_drops))
    plt.savefig("%s_drops.%s" % (number_of_drops, format))

# simulate raindrop 
# return total number of raindrop in circle and in square

def rain(number_of_drops=1000, length_of_field=1, plot=True, format='pdf', dynamic=False):
    """
    Function to make rain drops.
    """
    number_of_drops_in_circle = 0
    drops_in_circle = []
    drops_out_of_circle = []
    pi_estimate = []
    for k in range(number_of_drops):
        d = (rain_drop(length_of_field))
        if is_point_in_circle(d, length_of_field):
            drops_in_circle.append(d)
            number_of_drops_in_circle += 1
        else:
            drops_out_of_circle.append(d)
        if dynamic:  # The dynamic option if set to True will plot every new drop (this can be used to create animations of the simulation)
            print("Plotting drop number: %s" % (k + 1))
            plot_rain_drops(drops_in_circle, drops_out_of_circle, length_of_field, format)
        pi_estimate.append(4 * number_of_drops_in_circle / (k + 1))  # This updates the list with the newest estimate for pi.
    # Plot the pi estimates
    plt.figure()
    plt.scatter(range(1, number_of_drops + 1), pi_estimate)
    max_x = plt.xlim()[1]
    plt.hlines(math.pi, 0, max_x, color='black')
    plt.xlim(0, max_x)
    plt.title("$\pi$ estimate against number of rain drops")
    plt.xlabel("Number of rain drops")
    plt.ylabel("$\pi$")
    # plt.savefig("Pi_estimate_for_%s_drops_thrown.pdf" % number_of_drops)

    if plot and not dynamic:
        # If the plot option is passed and matplotlib is installed this plots
        # the final set of drops
        plot_rain_drops(drops_in_circle, drops_out_of_circle, length_of_field, format)

    return [number_of_drops_in_circle, number_of_drops]

# %%
# call the function 
number_of_drops = 500
r = rain(number_of_drops, plot=True, format='png', dynamic=False)

print("----------------------")
print("%s drops" % number_of_drops)
print("pi estimated as: %s " % (4 * r[0] / r[1]))
print("----------------------")

# call the function 
number_of_drops = 50000
r = rain(number_of_drops, plot=True, format='png', dynamic=False)

print("----------------------")
print("%s drops" % number_of_drops)
print("pi estimated as: %s " % (4 * r[0] / r[1]))
print("----------------------")
# Out:
# ----------------------
# 500 drops
# pi estimated as: 3.216
# ----------------------
# ----------------------
# 50000 drops
# pi estimated as: 3.14296
# ----------------------

# %% [markdown]
# ## Assignment 3
#
# 몬테카를로(Monte Carlo) 시뮬레이션을 통해 원주율 $\pi$ 를 근사한다고 하자.
#
# 위의 코드 예제에서 number_of_drops 값을 점차 증가시키면서 추정된 $\pi$ 의 값을 확인하시오.
#
# 어느 정도의 number_of_drops에서 $\pi$ 값이 약 3.14에 수렴하기 시작하는지 기록하시오.
#
# 결과를 서술형으로 답변란에 작성하시오.

# %%
''' Assignment 3 '''
'''
몬테카를로 시뮬레이션은 임의의 표본을 통해 어떤 값의 근사치를 구하는 방법을 말한다.
이와 같은 방법으로 원주율을 구한다고 가정했을 때 표본이 적으면 오차가 클 수 있다.

실제로 시뮬레이션 실행해보면 number_of_drops: 500 일 때 추정치는 약 3.216였지만,
number_of_drops: 50,000으로 늘리면 3.14296로 조금 더 pi 값에 근접한 것을 확인할 수 있었다.

이는 곧 큰수의 법칙에 따른 결과이다.
따라서 number_of_drops 값을 얼마나 증가해야지 결과가 3.14 수렴하는지 확인하는 것만이 남았다.

이를 검증하기 위해, 각 표본 케이스에서 시뮬레이션을 10회 반복 수행하고
그 중 9회 이상에서 3.14에 근접하는 경우에만 수렴하는 케이스로 판별하였다.
(최초 테스트는 100회 중 95회 승인을 기준으로 진행하였으나, 시뮬레이션 시간이 길어짐에 따라 830,000부터는 10회로 기준 변경 진행)

실험을 10,000부터 10,000씩 값을 증가시키며 진행한 결과, 
number_of_drops 값이 860,000 이상일 때부터 추정치가 안정적으로 3.14에 수렴한다고 할 수 있었다.
'''
# Out:
# '\n몬테카를로 시뮬레이션은 임의의 표본을 통해 결과의 근사치를 얻는 방법을 말한다.\n이와 같은 방법으로 원주율을 구한다고 가정했을 때 표본이 적으면 오차가 클 수 있다.\n\n실제로 위 시뮬레이션 결과를 보면 number_of_drops 값이 500일때는 추정치가 3.112로 확인되지만,\nnumber_of_drops 값을 50,000으로 늘리면 3.14632로 조금 더 pi 값에 근접한 것을 알 수 있다.\n\n바로 이 시뮬레이션이 큰수의 법칙에 기반하기 때문이다.\n그렇다면 number_of_drops 값이 얼마나 증가해야지 결과 값이 3.14에 수렴하기 할 수 있는지 확인하는 것만이 남았다.\n\n이를 시험을 통해 확인해보려고 한다.\n다만, 표본 데이터에 이상치가 들어있을 수 있기에 100번에 시뮬레이션 중 95번 이상 3.14에 근접하는 경우에만 수렴하는 케이스로 판별하려고 한다.\n\n\n'

# %%
import math

def convergence_point(start=50000, step=10000, window=100, threshold=0.95):
    required = int(window * threshold)  # 최소 만족 개수

    n = start

    while True:
        success_case_count = 0
        fail_case_count = 0
        
        for i in range(window):
            r = rain(n, plot=True, dynamic=False)
            v = (4 * r[0] / r[1])

            if int(v * 100) == 314:
                success_case_count += 1
            else:
                fail_case_count += 1

            print(f"{n} 케이스: 성공 - {success_case_count} / 실패 - {fail_case_count}")

            if fail_case_count >= (window - window * threshold):
                print(f"케이스 실패: {n}")
                break

        if success_case_count >= window * threshold:
            break
            
        n += step
    
    return n
    
point = convergence_point(start=50000, step=10000, window=100, threshold=0.95)
print("수렴 케이스:", point)
# Out:
# 50000 케이스: 성공 - 0 / 실패 - 1
# 50000 케이스: 성공 - 0 / 실패 - 2
# 50000 케이스: 성공 - 0 / 실패 - 3
# 50000 케이스: 성공 - 0 / 실패 - 4
# 50000 케이스: 성공 - 1 / 실패 - 4
# 50000 케이스: 성공 - 1 / 실패 - 5
# 케이스 실패: 50000
# 60000 케이스: 성공 - 0 / 실패 - 1
# 60000 케이스: 성공 - 0 / 실패 - 2
# 60000 케이스: 성공 - 1 / 실패 - 2
# 60000 케이스: 성공 - 2 / 실패 - 2
# /var/folders/hz/hyh3x0dx2yz6y9glqjv9qt1m0000gn/T/ipykernel_87106/2867468761.py:62: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   plt.figure()
# 60000 케이스: 성공 - 3 / 실패 - 2
# 60000 케이스: 성공 - 3 / 실패 - 3
# 60000 케이스: 성공 - 4 / 실패 - 3
# 60000 케이스: 성공 - 5 / 실패 - 3
# 60000 케이스: 성공 - 5 / 실패 - 4
# 60000 케이스: 성공 - 5 / 실패 - 5
# 케이스 실패: 60000
# 70000 케이스: 성공 - 1 / 실패 - 0
# 70000 케이스: 성공 - 2 / 실패 - 0
# 70000 케이스: 성공 - 2 / 실패 - 1
# 70000 케이스: 성공 - 2 / 실패 - 2
# 70000 케이스: 성공 - 3 / 실패 - 2
# 70000 케이스: 성공 - 4 / 실패 - 2
# 70000 케이스: 성공 - 4 / 실패 - 3
# 70000 케이스: 성공 - 5 / 실패 - 3
# 70000 케이스: 성공 - 6 / 실패 - 3
# 70000 케이스: 성공 - 6 / 실패 - 4
# 70000 케이스: 성공 - 6 / 실패 - 5
# 케이스 실패: 70000
# 80000 케이스: 성공 - 1 / 실패 - 0
# 80000 케이스: 성공 - 1 / 실패 - 1
# 80000 케이스: 성공 - 1 / 실패 - 2
# 80000 케이스: 성공 - 2 / 실패 - 2
# 80000 케이스: 성공 - 3 / 실패 - 2
# 80000 케이스: 성공 - 3 / 실패 - 3
# 80000 케이스: 성공 - 4 / 실패 - 3
# 80000 케이스: 성공 - 4 / 실패 - 4
# 80000 케이스: 성공 - 5 / 실패 - 4
# 80000 케이스: 성공 - 6 / 실패 - 4
# 80000 케이스: 성공 - 7 / 실패 - 4
# 80000 케이스: 성공 - 8 / 실패 - 4
# 80000 케이스: 성공 - 8 / 실패 - 5
# 케이스 실패: 80000
# 90000 케이스: 성공 - 1 / 실패 - 0
# 90000 케이스: 성공 - 1 / 실패 - 1
# 90000 케이스: 성공 - 1 / 실패 - 2
# 90000 케이스: 성공 - 2 / 실패 - 2
# 90000 케이스: 성공 - 3 / 실패 - 2
# 90000 케이스: 성공 - 4 / 실패 - 2
# 90000 케이스: 성공 - 4 / 실패 - 3
# 90000 케이스: 성공 - 4 / 실패 - 4
# 90000 케이스: 성공 - 4 / 실패 - 5
# 케이스 실패: 90000
# 100000 케이스: 성공 - 0 / 실패 - 1
# 100000 케이스: 성공 - 0 / 실패 - 2
# 100000 케이스: 성공 - 0 / 실패 - 3
# 100000 케이스: 성공 - 0 / 실패 - 4
# 100000 케이스: 성공 - 1 / 실패 - 4
# 100000 케이스: 성공 - 2 / 실패 - 4
# 100000 케이스: 성공 - 3 / 실패 - 4
# 100000 케이스: 성공 - 4 / 실패 - 4
# 100000 케이스: 성공 - 5 / 실패 - 4
# 100000 케이스: 성공 - 5 / 실패 - 5
# 케이스 실패: 100000
# 110000 케이스: 성공 - 1 / 실패 - 0
# 110000 케이스: 성공 - 2 / 실패 - 0
# 110000 케이스: 성공 - 2 / 실패 - 1
# 110000 케이스: 성공 - 3 / 실패 - 1
# 110000 케이스: 성공 - 4 / 실패 - 1
# 110000 케이스: 성공 - 5 / 실패 - 1
# 110000 케이스: 성공 - 6 / 실패 - 1
# 110000 케이스: 성공 - 6 / 실패 - 2
# 110000 케이스: 성공 - 7 / 실패 - 2
# 110000 케이스: 성공 - 8 / 실패 - 2
# 110000 케이스: 성공 - 8 / 실패 - 3
# 110000 케이스: 성공 - 9 / 실패 - 3
# 110000 케이스: 성공 - 9 / 실패 - 4
# 110000 케이스: 성공 - 10 / 실패 - 4
# 110000 케이스: 성공 - 10 / 실패 - 5
# 케이스 실패: 110000
# 120000 케이스: 성공 - 1 / 실패 - 0
# 120000 케이스: 성공 - 1 / 실패 - 1
# 120000 케이스: 성공 - 1 / 실패 - 2
# 120000 케이스: 성공 - 1 / 실패 - 3
# 120000 케이스: 성공 - 2 / 실패 - 3
# 120000 케이스: 성공 - 2 / 실패 - 4
# 120000 케이스: 성공 - 3 / 실패 - 4
# 120000 케이스: 성공 - 4 / 실패 - 4
# 120000 케이스: 성공 - 5 / 실패 - 4
# 120000 케이스: 성공 - 6 / 실패 - 4
# 120000 케이스: 성공 - 7 / 실패 - 4
# 120000 케이스: 성공 - 7 / 실패 - 5
# 케이스 실패: 120000
# 130000 케이스: 성공 - 1 / 실패 - 0
# 130000 케이스: 성공 - 2 / 실패 - 0
# 130000 케이스: 성공 - 3 / 실패 - 0
# 130000 케이스: 성공 - 4 / 실패 - 0
# 130000 케이스: 성공 - 5 / 실패 - 0
# 130000 케이스: 성공 - 6 / 실패 - 0
# 130000 케이스: 성공 - 6 / 실패 - 1
# 130000 케이스: 성공 - 7 / 실패 - 1
# 130000 케이스: 성공 - 8 / 실패 - 1
# 130000 케이스: 성공 - 9 / 실패 - 1
# 130000 케이스: 성공 - 9 / 실패 - 2
# 130000 케이스: 성공 - 10 / 실패 - 2
# 130000 케이스: 성공 - 11 / 실패 - 2
# 130000 케이스: 성공 - 11 / 실패 - 3
# 130000 케이스: 성공 - 11 / 실패 - 4
# 130000 케이스: 성공 - 12 / 실패 - 4
# 130000 케이스: 성공 - 13 / 실패 - 4
# 130000 케이스: 성공 - 13 / 실패 - 5
# 케이스 실패: 130000
# 140000 케이스: 성공 - 1 / 실패 - 0
# 140000 케이스: 성공 - 2 / 실패 - 0
# 140000 케이스: 성공 - 3 / 실패 - 0
# 140000 케이스: 성공 - 3 / 실패 - 1
# 140000 케이스: 성공 - 4 / 실패 - 1
# 140000 케이스: 성공 - 4 / 실패 - 2
# 140000 케이스: 성공 - 5 / 실패 - 2
# 140000 케이스: 성공 - 5 / 실패 - 3
# 140000 케이스: 성공 - 6 / 실패 - 3
# 140000 케이스: 성공 - 7 / 실패 - 3
# 140000 케이스: 성공 - 7 / 실패 - 4
# 140000 케이스: 성공 - 7 / 실패 - 5
# 케이스 실패: 140000
# 150000 케이스: 성공 - 0 / 실패 - 1
# 150000 케이스: 성공 - 0 / 실패 - 2
# 150000 케이스: 성공 - 1 / 실패 - 2
# 150000 케이스: 성공 - 1 / 실패 - 3
# 150000 케이스: 성공 - 2 / 실패 - 3
# 150000 케이스: 성공 - 3 / 실패 - 3
# 150000 케이스: 성공 - 4 / 실패 - 3
# 150000 케이스: 성공 - 4 / 실패 - 4
# 150000 케이스: 성공 - 5 / 실패 - 4
# 150000 케이스: 성공 - 5 / 실패 - 5
# 케이스 실패: 150000
# 160000 케이스: 성공 - 1 / 실패 - 0
# 160000 케이스: 성공 - 1 / 실패 - 1
# 160000 케이스: 성공 - 2 / 실패 - 1
# 160000 케이스: 성공 - 3 / 실패 - 1
# 160000 케이스: 성공 - 4 / 실패 - 1
# 160000 케이스: 성공 - 4 / 실패 - 2
# 160000 케이스: 성공 - 5 / 실패 - 2
# 160000 케이스: 성공 - 6 / 실패 - 2
# 160000 케이스: 성공 - 6 / 실패 - 3
# 160000 케이스: 성공 - 6 / 실패 - 4
# 160000 케이스: 성공 - 6 / 실패 - 5
# 케이스 실패: 160000
# 170000 케이스: 성공 - 1 / 실패 - 0
# 170000 케이스: 성공 - 2 / 실패 - 0
# 170000 케이스: 성공 - 3 / 실패 - 0
# 170000 케이스: 성공 - 3 / 실패 - 1
# 170000 케이스: 성공 - 4 / 실패 - 1
# 170000 케이스: 성공 - 4 / 실패 - 2
# 170000 케이스: 성공 - 4 / 실패 - 3
# 170000 케이스: 성공 - 5 / 실패 - 3
# 170000 케이스: 성공 - 6 / 실패 - 3
# 170000 케이스: 성공 - 7 / 실패 - 3
# 170000 케이스: 성공 - 8 / 실패 - 3
# 170000 케이스: 성공 - 9 / 실패 - 3
# 170000 케이스: 성공 - 10 / 실패 - 3
# 170000 케이스: 성공 - 11 / 실패 - 3
# 170000 케이스: 성공 - 11 / 실패 - 4
# 170000 케이스: 성공 - 12 / 실패 - 4
# 170000 케이스: 성공 - 13 / 실패 - 4
# 170000 케이스: 성공 - 13 / 실패 - 5
# 케이스 실패: 170000
# 180000 케이스: 성공 - 1 / 실패 - 0
# 180000 케이스: 성공 - 1 / 실패 - 1
# 180000 케이스: 성공 - 2 / 실패 - 1
# 180000 케이스: 성공 - 3 / 실패 - 1
# 180000 케이스: 성공 - 4 / 실패 - 1
# 180000 케이스: 성공 - 4 / 실패 - 2
# 180000 케이스: 성공 - 4 / 실패 - 3
# 180000 케이스: 성공 - 4 / 실패 - 4
# 180000 케이스: 성공 - 4 / 실패 - 5
# 케이스 실패: 180000
# 190000 케이스: 성공 - 0 / 실패 - 1
# 190000 케이스: 성공 - 1 / 실패 - 1
# 190000 케이스: 성공 - 1 / 실패 - 2
# 190000 케이스: 성공 - 2 / 실패 - 2
# 190000 케이스: 성공 - 3 / 실패 - 2
# 190000 케이스: 성공 - 4 / 실패 - 2
# 190000 케이스: 성공 - 5 / 실패 - 2
# 190000 케이스: 성공 - 5 / 실패 - 3
# 190000 케이스: 성공 - 6 / 실패 - 3
# 190000 케이스: 성공 - 6 / 실패 - 4
# 190000 케이스: 성공 - 7 / 실패 - 4
# 190000 케이스: 성공 - 7 / 실패 - 5
# 케이스 실패: 190000
# 200000 케이스: 성공 - 0 / 실패 - 1
# 200000 케이스: 성공 - 1 / 실패 - 1
# 200000 케이스: 성공 - 2 / 실패 - 1
# 200000 케이스: 성공 - 3 / 실패 - 1
# 200000 케이스: 성공 - 4 / 실패 - 1
# 200000 케이스: 성공 - 4 / 실패 - 2
# 200000 케이스: 성공 - 5 / 실패 - 2
# 200000 케이스: 성공 - 6 / 실패 - 2
# 200000 케이스: 성공 - 6 / 실패 - 3
# 200000 케이스: 성공 - 6 / 실패 - 4
# 200000 케이스: 성공 - 7 / 실패 - 4
# 200000 케이스: 성공 - 7 / 실패 - 5
# 케이스 실패: 200000
# 210000 케이스: 성공 - 1 / 실패 - 0
# 210000 케이스: 성공 - 2 / 실패 - 0
# 210000 케이스: 성공 - 3 / 실패 - 0
# 210000 케이스: 성공 - 3 / 실패 - 1
# 210000 케이스: 성공 - 4 / 실패 - 1
# 210000 케이스: 성공 - 4 / 실패 - 2
# 210000 케이스: 성공 - 4 / 실패 - 3
# 210000 케이스: 성공 - 5 / 실패 - 3
# 210000 케이스: 성공 - 6 / 실패 - 3
# 210000 케이스: 성공 - 7 / 실패 - 3
# 210000 케이스: 성공 - 8 / 실패 - 3
# 210000 케이스: 성공 - 8 / 실패 - 4
# 210000 케이스: 성공 - 9 / 실패 - 4
# 210000 케이스: 성공 - 10 / 실패 - 4
# 210000 케이스: 성공 - 11 / 실패 - 4
# 210000 케이스: 성공 - 12 / 실패 - 4
# 210000 케이스: 성공 - 13 / 실패 - 4
# 210000 케이스: 성공 - 14 / 실패 - 4
# 210000 케이스: 성공 - 15 / 실패 - 4
# 210000 케이스: 성공 - 15 / 실패 - 5
# 케이스 실패: 210000
# 220000 케이스: 성공 - 0 / 실패 - 1
# 220000 케이스: 성공 - 0 / 실패 - 2
# 220000 케이스: 성공 - 1 / 실패 - 2
# 220000 케이스: 성공 - 2 / 실패 - 2
# 220000 케이스: 성공 - 3 / 실패 - 2
# 220000 케이스: 성공 - 3 / 실패 - 3
# 220000 케이스: 성공 - 4 / 실패 - 3
# 220000 케이스: 성공 - 4 / 실패 - 4
# 220000 케이스: 성공 - 5 / 실패 - 4
# 220000 케이스: 성공 - 6 / 실패 - 4
# 220000 케이스: 성공 - 6 / 실패 - 5
# 케이스 실패: 220000
# 230000 케이스: 성공 - 1 / 실패 - 0
# 230000 케이스: 성공 - 2 / 실패 - 0
# 230000 케이스: 성공 - 2 / 실패 - 1
# 230000 케이스: 성공 - 3 / 실패 - 1
# 230000 케이스: 성공 - 3 / 실패 - 2
# 230000 케이스: 성공 - 3 / 실패 - 3
# 230000 케이스: 성공 - 3 / 실패 - 4
# 230000 케이스: 성공 - 4 / 실패 - 4
# 230000 케이스: 성공 - 5 / 실패 - 4
# 230000 케이스: 성공 - 6 / 실패 - 4
# 230000 케이스: 성공 - 6 / 실패 - 5
# 케이스 실패: 230000
# 240000 케이스: 성공 - 1 / 실패 - 0
# 240000 케이스: 성공 - 1 / 실패 - 1
# 240000 케이스: 성공 - 2 / 실패 - 1
# 240000 케이스: 성공 - 2 / 실패 - 2
# 240000 케이스: 성공 - 2 / 실패 - 3
# 240000 케이스: 성공 - 3 / 실패 - 3
# 240000 케이스: 성공 - 3 / 실패 - 4
# 240000 케이스: 성공 - 3 / 실패 - 5
# 케이스 실패: 240000
# 250000 케이스: 성공 - 0 / 실패 - 1
# 250000 케이스: 성공 - 1 / 실패 - 1
# 250000 케이스: 성공 - 2 / 실패 - 1
# 250000 케이스: 성공 - 3 / 실패 - 1
# 250000 케이스: 성공 - 4 / 실패 - 1
# 250000 케이스: 성공 - 4 / 실패 - 2
# 250000 케이스: 성공 - 5 / 실패 - 2
# 250000 케이스: 성공 - 6 / 실패 - 2
# 250000 케이스: 성공 - 6 / 실패 - 3
# 250000 케이스: 성공 - 7 / 실패 - 3
# 250000 케이스: 성공 - 8 / 실패 - 3
# 250000 케이스: 성공 - 9 / 실패 - 3
# 250000 케이스: 성공 - 10 / 실패 - 3
# 250000 케이스: 성공 - 11 / 실패 - 3
# 250000 케이스: 성공 - 12 / 실패 - 3
# 250000 케이스: 성공 - 13 / 실패 - 3
# 250000 케이스: 성공 - 14 / 실패 - 3
# 250000 케이스: 성공 - 15 / 실패 - 3
# 250000 케이스: 성공 - 16 / 실패 - 3
# 250000 케이스: 성공 - 16 / 실패 - 4
# 250000 케이스: 성공 - 17 / 실패 - 4
# 250000 케이스: 성공 - 18 / 실패 - 4
# 250000 케이스: 성공 - 19 / 실패 - 4
# 250000 케이스: 성공 - 20 / 실패 - 4
# 250000 케이스: 성공 - 20 / 실패 - 5
# 케이스 실패: 250000
# 260000 케이스: 성공 - 0 / 실패 - 1
# 260000 케이스: 성공 - 1 / 실패 - 1
# 260000 케이스: 성공 - 2 / 실패 - 1
# 260000 케이스: 성공 - 3 / 실패 - 1
# 260000 케이스: 성공 - 3 / 실패 - 2
# 260000 케이스: 성공 - 4 / 실패 - 2
# 260000 케이스: 성공 - 5 / 실패 - 2
# 260000 케이스: 성공 - 6 / 실패 - 2
# 260000 케이스: 성공 - 7 / 실패 - 2
# 260000 케이스: 성공 - 8 / 실패 - 2
# 260000 케이스: 성공 - 9 / 실패 - 2
# 260000 케이스: 성공 - 10 / 실패 - 2
# 260000 케이스: 성공 - 11 / 실패 - 2
# 260000 케이스: 성공 - 11 / 실패 - 3
# 260000 케이스: 성공 - 12 / 실패 - 3
# 260000 케이스: 성공 - 13 / 실패 - 3
# 260000 케이스: 성공 - 14 / 실패 - 3
# 260000 케이스: 성공 - 15 / 실패 - 3
# 260000 케이스: 성공 - 16 / 실패 - 3
# 260000 케이스: 성공 - 16 / 실패 - 4
# 260000 케이스: 성공 - 16 / 실패 - 5
# 케이스 실패: 260000
# 270000 케이스: 성공 - 1 / 실패 - 0
# 270000 케이스: 성공 - 2 / 실패 - 0
# 270000 케이스: 성공 - 3 / 실패 - 0
# 270000 케이스: 성공 - 3 / 실패 - 1
# 270000 케이스: 성공 - 3 / 실패 - 2
# 270000 케이스: 성공 - 3 / 실패 - 3
# 270000 케이스: 성공 - 4 / 실패 - 3
# 270000 케이스: 성공 - 4 / 실패 - 4
# 270000 케이스: 성공 - 4 / 실패 - 5
# 케이스 실패: 270000
# 280000 케이스: 성공 - 1 / 실패 - 0
# 280000 케이스: 성공 - 2 / 실패 - 0
# 280000 케이스: 성공 - 3 / 실패 - 0
# 280000 케이스: 성공 - 4 / 실패 - 0
# 280000 케이스: 성공 - 4 / 실패 - 1
# 280000 케이스: 성공 - 4 / 실패 - 2
# 280000 케이스: 성공 - 4 / 실패 - 3
# 280000 케이스: 성공 - 5 / 실패 - 3
# 280000 케이스: 성공 - 6 / 실패 - 3
# 280000 케이스: 성공 - 7 / 실패 - 3
# 280000 케이스: 성공 - 7 / 실패 - 4
# 280000 케이스: 성공 - 7 / 실패 - 5
# 케이스 실패: 280000
# 290000 케이스: 성공 - 1 / 실패 - 0
# 290000 케이스: 성공 - 2 / 실패 - 0
# 290000 케이스: 성공 - 2 / 실패 - 1
# 290000 케이스: 성공 - 3 / 실패 - 1
# 290000 케이스: 성공 - 4 / 실패 - 1
# 290000 케이스: 성공 - 5 / 실패 - 1
# 290000 케이스: 성공 - 6 / 실패 - 1
# 290000 케이스: 성공 - 6 / 실패 - 2
# 290000 케이스: 성공 - 7 / 실패 - 2
# 290000 케이스: 성공 - 8 / 실패 - 2
# 290000 케이스: 성공 - 9 / 실패 - 2
# 290000 케이스: 성공 - 10 / 실패 - 2
# 290000 케이스: 성공 - 11 / 실패 - 2
# 290000 케이스: 성공 - 11 / 실패 - 3
# 290000 케이스: 성공 - 12 / 실패 - 3
# 290000 케이스: 성공 - 13 / 실패 - 3
# 290000 케이스: 성공 - 14 / 실패 - 3
# 290000 케이스: 성공 - 15 / 실패 - 3
# 290000 케이스: 성공 - 16 / 실패 - 3
# 290000 케이스: 성공 - 16 / 실패 - 4
# 290000 케이스: 성공 - 16 / 실패 - 5
# 케이스 실패: 290000
# 300000 케이스: 성공 - 1 / 실패 - 0
# 300000 케이스: 성공 - 1 / 실패 - 1
# 300000 케이스: 성공 - 2 / 실패 - 1
# 300000 케이스: 성공 - 3 / 실패 - 1
# 300000 케이스: 성공 - 4 / 실패 - 1
# 300000 케이스: 성공 - 5 / 실패 - 1
# 300000 케이스: 성공 - 6 / 실패 - 1
# 300000 케이스: 성공 - 7 / 실패 - 1
# 300000 케이스: 성공 - 8 / 실패 - 1
# 300000 케이스: 성공 - 9 / 실패 - 1
# 300000 케이스: 성공 - 9 / 실패 - 2
# 300000 케이스: 성공 - 10 / 실패 - 2
# 300000 케이스: 성공 - 10 / 실패 - 3
# 300000 케이스: 성공 - 11 / 실패 - 3
# 300000 케이스: 성공 - 12 / 실패 - 3
# 300000 케이스: 성공 - 13 / 실패 - 3
# 300000 케이스: 성공 - 14 / 실패 - 3
# 300000 케이스: 성공 - 15 / 실패 - 3
# 300000 케이스: 성공 - 15 / 실패 - 4
# 300000 케이스: 성공 - 16 / 실패 - 4
# 300000 케이스: 성공 - 16 / 실패 - 5
# 케이스 실패: 300000
# 310000 케이스: 성공 - 1 / 실패 - 0
# 310000 케이스: 성공 - 2 / 실패 - 0
# 310000 케이스: 성공 - 3 / 실패 - 0
# 310000 케이스: 성공 - 3 / 실패 - 1
# 310000 케이스: 성공 - 4 / 실패 - 1
# 310000 케이스: 성공 - 5 / 실패 - 1
# 310000 케이스: 성공 - 5 / 실패 - 2
# 310000 케이스: 성공 - 6 / 실패 - 2
# 310000 케이스: 성공 - 6 / 실패 - 3
# 310000 케이스: 성공 - 7 / 실패 - 3
# 310000 케이스: 성공 - 7 / 실패 - 4
# 310000 케이스: 성공 - 7 / 실패 - 5
# 케이스 실패: 310000
# 320000 케이스: 성공 - 1 / 실패 - 0
# 320000 케이스: 성공 - 2 / 실패 - 0
# 320000 케이스: 성공 - 3 / 실패 - 0
# 320000 케이스: 성공 - 4 / 실패 - 0
# 320000 케이스: 성공 - 5 / 실패 - 0
# 320000 케이스: 성공 - 6 / 실패 - 0
# 320000 케이스: 성공 - 7 / 실패 - 0
# 320000 케이스: 성공 - 7 / 실패 - 1
# 320000 케이스: 성공 - 8 / 실패 - 1
# 320000 케이스: 성공 - 8 / 실패 - 2
# 320000 케이스: 성공 - 9 / 실패 - 2
# 320000 케이스: 성공 - 10 / 실패 - 2
# 320000 케이스: 성공 - 11 / 실패 - 2
# 320000 케이스: 성공 - 12 / 실패 - 2
# 320000 케이스: 성공 - 13 / 실패 - 2
# 320000 케이스: 성공 - 14 / 실패 - 2
# 320000 케이스: 성공 - 15 / 실패 - 2
# 320000 케이스: 성공 - 16 / 실패 - 2
# 320000 케이스: 성공 - 17 / 실패 - 2
# 320000 케이스: 성공 - 18 / 실패 - 2
# 320000 케이스: 성공 - 18 / 실패 - 3
# 320000 케이스: 성공 - 18 / 실패 - 4
# 320000 케이스: 성공 - 19 / 실패 - 4
# 320000 케이스: 성공 - 20 / 실패 - 4
# 320000 케이스: 성공 - 20 / 실패 - 5
# 케이스 실패: 320000
# 330000 케이스: 성공 - 1 / 실패 - 0
# 330000 케이스: 성공 - 1 / 실패 - 1
# 330000 케이스: 성공 - 2 / 실패 - 1
# 330000 케이스: 성공 - 2 / 실패 - 2
# 330000 케이스: 성공 - 2 / 실패 - 3
# 330000 케이스: 성공 - 3 / 실패 - 3
# 330000 케이스: 성공 - 4 / 실패 - 3
# 330000 케이스: 성공 - 5 / 실패 - 3
# 330000 케이스: 성공 - 6 / 실패 - 3
# 330000 케이스: 성공 - 7 / 실패 - 3
# 330000 케이스: 성공 - 8 / 실패 - 3
# 330000 케이스: 성공 - 9 / 실패 - 3
# 330000 케이스: 성공 - 9 / 실패 - 4
# 330000 케이스: 성공 - 10 / 실패 - 4
# 330000 케이스: 성공 - 11 / 실패 - 4
# 330000 케이스: 성공 - 12 / 실패 - 4
# 330000 케이스: 성공 - 13 / 실패 - 4
# 330000 케이스: 성공 - 14 / 실패 - 4
# 330000 케이스: 성공 - 15 / 실패 - 4
# 330000 케이스: 성공 - 16 / 실패 - 4
# 330000 케이스: 성공 - 17 / 실패 - 4
# 330000 케이스: 성공 - 18 / 실패 - 4
# 330000 케이스: 성공 - 19 / 실패 - 4
# 330000 케이스: 성공 - 19 / 실패 - 5
# 케이스 실패: 330000
# 340000 케이스: 성공 - 0 / 실패 - 1
# 340000 케이스: 성공 - 0 / 실패 - 2
# 340000 케이스: 성공 - 1 / 실패 - 2
# 340000 케이스: 성공 - 2 / 실패 - 2
# 340000 케이스: 성공 - 2 / 실패 - 3
# 340000 케이스: 성공 - 2 / 실패 - 4
# 340000 케이스: 성공 - 3 / 실패 - 4
# 340000 케이스: 성공 - 3 / 실패 - 5
# 케이스 실패: 340000
# 350000 케이스: 성공 - 1 / 실패 - 0
# 350000 케이스: 성공 - 2 / 실패 - 0
# 350000 케이스: 성공 - 3 / 실패 - 0
# 350000 케이스: 성공 - 4 / 실패 - 0
# 350000 케이스: 성공 - 4 / 실패 - 1
# 350000 케이스: 성공 - 5 / 실패 - 1
# 350000 케이스: 성공 - 6 / 실패 - 1
# 350000 케이스: 성공 - 7 / 실패 - 1
# 350000 케이스: 성공 - 7 / 실패 - 2
# 350000 케이스: 성공 - 8 / 실패 - 2
# 350000 케이스: 성공 - 9 / 실패 - 2
# 350000 케이스: 성공 - 10 / 실패 - 2
# 350000 케이스: 성공 - 11 / 실패 - 2
# 350000 케이스: 성공 - 11 / 실패 - 3
# 350000 케이스: 성공 - 11 / 실패 - 4
# 350000 케이스: 성공 - 11 / 실패 - 5
# 케이스 실패: 350000
# 360000 케이스: 성공 - 1 / 실패 - 0
# 360000 케이스: 성공 - 2 / 실패 - 0
# 360000 케이스: 성공 - 2 / 실패 - 1
# 360000 케이스: 성공 - 2 / 실패 - 2
# 360000 케이스: 성공 - 2 / 실패 - 3
# 360000 케이스: 성공 - 3 / 실패 - 3
# 360000 케이스: 성공 - 4 / 실패 - 3
# 360000 케이스: 성공 - 5 / 실패 - 3
# 360000 케이스: 성공 - 5 / 실패 - 4
# 360000 케이스: 성공 - 5 / 실패 - 5
# 케이스 실패: 360000
# 370000 케이스: 성공 - 1 / 실패 - 0
# 370000 케이스: 성공 - 1 / 실패 - 1
# 370000 케이스: 성공 - 2 / 실패 - 1
# 370000 케이스: 성공 - 2 / 실패 - 2
# 370000 케이스: 성공 - 3 / 실패 - 2
# 370000 케이스: 성공 - 4 / 실패 - 2
# 370000 케이스: 성공 - 5 / 실패 - 2
# 370000 케이스: 성공 - 6 / 실패 - 2
# 370000 케이스: 성공 - 7 / 실패 - 2
# 370000 케이스: 성공 - 8 / 실패 - 2
# 370000 케이스: 성공 - 9 / 실패 - 2
# 370000 케이스: 성공 - 10 / 실패 - 2
# 370000 케이스: 성공 - 10 / 실패 - 3
# 370000 케이스: 성공 - 11 / 실패 - 3
# 370000 케이스: 성공 - 11 / 실패 - 4
# 370000 케이스: 성공 - 12 / 실패 - 4
# 370000 케이스: 성공 - 12 / 실패 - 5
# 케이스 실패: 370000
# 380000 케이스: 성공 - 1 / 실패 - 0
# 380000 케이스: 성공 - 2 / 실패 - 0
# 380000 케이스: 성공 - 3 / 실패 - 0
# 380000 케이스: 성공 - 3 / 실패 - 1
# 380000 케이스: 성공 - 4 / 실패 - 1
# 380000 케이스: 성공 - 4 / 실패 - 2
# 380000 케이스: 성공 - 5 / 실패 - 2
# 380000 케이스: 성공 - 5 / 실패 - 3
# 380000 케이스: 성공 - 6 / 실패 - 3
# 380000 케이스: 성공 - 7 / 실패 - 3
# 380000 케이스: 성공 - 8 / 실패 - 3
# 380000 케이스: 성공 - 9 / 실패 - 3
# 380000 케이스: 성공 - 10 / 실패 - 3
# 380000 케이스: 성공 - 11 / 실패 - 3
# 380000 케이스: 성공 - 12 / 실패 - 3
# 380000 케이스: 성공 - 13 / 실패 - 3
# 380000 케이스: 성공 - 13 / 실패 - 4
# 380000 케이스: 성공 - 13 / 실패 - 5
# 케이스 실패: 380000
# 390000 케이스: 성공 - 1 / 실패 - 0
# 390000 케이스: 성공 - 2 / 실패 - 0
# 390000 케이스: 성공 - 3 / 실패 - 0
# 390000 케이스: 성공 - 3 / 실패 - 1
# 390000 케이스: 성공 - 3 / 실패 - 2
# 390000 케이스: 성공 - 3 / 실패 - 3
# 390000 케이스: 성공 - 3 / 실패 - 4
# 390000 케이스: 성공 - 4 / 실패 - 4
# 390000 케이스: 성공 - 5 / 실패 - 4
# 390000 케이스: 성공 - 5 / 실패 - 5
# 케이스 실패: 390000
# 400000 케이스: 성공 - 1 / 실패 - 0
# 400000 케이스: 성공 - 2 / 실패 - 0
# 400000 케이스: 성공 - 2 / 실패 - 1
# 400000 케이스: 성공 - 2 / 실패 - 2
# 400000 케이스: 성공 - 2 / 실패 - 3
# 400000 케이스: 성공 - 3 / 실패 - 3
# 400000 케이스: 성공 - 4 / 실패 - 3
# 400000 케이스: 성공 - 5 / 실패 - 3
# 400000 케이스: 성공 - 6 / 실패 - 3
# 400000 케이스: 성공 - 6 / 실패 - 4
# 400000 케이스: 성공 - 7 / 실패 - 4
# 400000 케이스: 성공 - 8 / 실패 - 4
# 400000 케이스: 성공 - 9 / 실패 - 4
# 400000 케이스: 성공 - 10 / 실패 - 4
# 400000 케이스: 성공 - 11 / 실패 - 4
# 400000 케이스: 성공 - 11 / 실패 - 5
# 케이스 실패: 400000
# 410000 케이스: 성공 - 1 / 실패 - 0
# 410000 케이스: 성공 - 2 / 실패 - 0
# 410000 케이스: 성공 - 3 / 실패 - 0
# 410000 케이스: 성공 - 4 / 실패 - 0
# 410000 케이스: 성공 - 5 / 실패 - 0
# 410000 케이스: 성공 - 6 / 실패 - 0
# 410000 케이스: 성공 - 7 / 실패 - 0
# 410000 케이스: 성공 - 8 / 실패 - 0
# 410000 케이스: 성공 - 9 / 실패 - 0
# 410000 케이스: 성공 - 10 / 실패 - 0
# 410000 케이스: 성공 - 11 / 실패 - 0
# 410000 케이스: 성공 - 12 / 실패 - 0
# 410000 케이스: 성공 - 13 / 실패 - 0
# 410000 케이스: 성공 - 13 / 실패 - 1
# 410000 케이스: 성공 - 14 / 실패 - 1
# 410000 케이스: 성공 - 15 / 실패 - 1
# 410000 케이스: 성공 - 16 / 실패 - 1
# 410000 케이스: 성공 - 17 / 실패 - 1
# 410000 케이스: 성공 - 18 / 실패 - 1
# 410000 케이스: 성공 - 19 / 실패 - 1
# 410000 케이스: 성공 - 19 / 실패 - 2
# 410000 케이스: 성공 - 20 / 실패 - 2
# 410000 케이스: 성공 - 21 / 실패 - 2
# 410000 케이스: 성공 - 22 / 실패 - 2
# 410000 케이스: 성공 - 23 / 실패 - 2
# 410000 케이스: 성공 - 23 / 실패 - 3
# 410000 케이스: 성공 - 24 / 실패 - 3
# 410000 케이스: 성공 - 25 / 실패 - 3
# 410000 케이스: 성공 - 26 / 실패 - 3
# 410000 케이스: 성공 - 26 / 실패 - 4
# 410000 케이스: 성공 - 27 / 실패 - 4
# 410000 케이스: 성공 - 27 / 실패 - 5
# 케이스 실패: 410000
# 420000 케이스: 성공 - 1 / 실패 - 0
# 420000 케이스: 성공 - 2 / 실패 - 0
# 420000 케이스: 성공 - 3 / 실패 - 0
# 420000 케이스: 성공 - 3 / 실패 - 1
# 420000 케이스: 성공 - 3 / 실패 - 2
# 420000 케이스: 성공 - 3 / 실패 - 3
# 420000 케이스: 성공 - 4 / 실패 - 3
# 420000 케이스: 성공 - 4 / 실패 - 4
# 420000 케이스: 성공 - 4 / 실패 - 5
# 케이스 실패: 420000
# 430000 케이스: 성공 - 1 / 실패 - 0
# 430000 케이스: 성공 - 2 / 실패 - 0
# 430000 케이스: 성공 - 3 / 실패 - 0
# 430000 케이스: 성공 - 4 / 실패 - 0
# 430000 케이스: 성공 - 5 / 실패 - 0
# 430000 케이스: 성공 - 6 / 실패 - 0
# 430000 케이스: 성공 - 7 / 실패 - 0
# 430000 케이스: 성공 - 8 / 실패 - 0
# 430000 케이스: 성공 - 9 / 실패 - 0
# 430000 케이스: 성공 - 10 / 실패 - 0
# 430000 케이스: 성공 - 11 / 실패 - 0
# 430000 케이스: 성공 - 12 / 실패 - 0
# 430000 케이스: 성공 - 13 / 실패 - 0
# 430000 케이스: 성공 - 13 / 실패 - 1
# 430000 케이스: 성공 - 14 / 실패 - 1
# 430000 케이스: 성공 - 15 / 실패 - 1
# 430000 케이스: 성공 - 16 / 실패 - 1
# 430000 케이스: 성공 - 16 / 실패 - 2
# 430000 케이스: 성공 - 17 / 실패 - 2
# 430000 케이스: 성공 - 18 / 실패 - 2
# 430000 케이스: 성공 - 19 / 실패 - 2
# 430000 케이스: 성공 - 19 / 실패 - 3
# 430000 케이스: 성공 - 20 / 실패 - 3
# 430000 케이스: 성공 - 21 / 실패 - 3
# 430000 케이스: 성공 - 22 / 실패 - 3
# 430000 케이스: 성공 - 23 / 실패 - 3
# 430000 케이스: 성공 - 23 / 실패 - 4
# 430000 케이스: 성공 - 24 / 실패 - 4
# 430000 케이스: 성공 - 25 / 실패 - 4
# 430000 케이스: 성공 - 26 / 실패 - 4
# 430000 케이스: 성공 - 27 / 실패 - 4
# 430000 케이스: 성공 - 27 / 실패 - 5
# 케이스 실패: 430000
# 440000 케이스: 성공 - 0 / 실패 - 1
# 440000 케이스: 성공 - 1 / 실패 - 1
# 440000 케이스: 성공 - 2 / 실패 - 1
# 440000 케이스: 성공 - 3 / 실패 - 1
# 440000 케이스: 성공 - 4 / 실패 - 1
# 440000 케이스: 성공 - 5 / 실패 - 1
# 440000 케이스: 성공 - 6 / 실패 - 1
# 440000 케이스: 성공 - 7 / 실패 - 1
# 440000 케이스: 성공 - 7 / 실패 - 2
# 440000 케이스: 성공 - 8 / 실패 - 2
# 440000 케이스: 성공 - 9 / 실패 - 2
# 440000 케이스: 성공 - 9 / 실패 - 3
# 440000 케이스: 성공 - 10 / 실패 - 3
# 440000 케이스: 성공 - 10 / 실패 - 4
# 440000 케이스: 성공 - 11 / 실패 - 4
# 440000 케이스: 성공 - 12 / 실패 - 4
# 440000 케이스: 성공 - 13 / 실패 - 4
# 440000 케이스: 성공 - 13 / 실패 - 5
# 케이스 실패: 440000
# 450000 케이스: 성공 - 1 / 실패 - 0
# 450000 케이스: 성공 - 2 / 실패 - 0
# 450000 케이스: 성공 - 3 / 실패 - 0
# 450000 케이스: 성공 - 4 / 실패 - 0
# 450000 케이스: 성공 - 4 / 실패 - 1
# 450000 케이스: 성공 - 5 / 실패 - 1
# 450000 케이스: 성공 - 6 / 실패 - 1
# 450000 케이스: 성공 - 7 / 실패 - 1
# 450000 케이스: 성공 - 8 / 실패 - 1
# 450000 케이스: 성공 - 9 / 실패 - 1
# 450000 케이스: 성공 - 10 / 실패 - 1
# 450000 케이스: 성공 - 11 / 실패 - 1
# 450000 케이스: 성공 - 11 / 실패 - 2
# 450000 케이스: 성공 - 12 / 실패 - 2
# 450000 케이스: 성공 - 12 / 실패 - 3
# 450000 케이스: 성공 - 13 / 실패 - 3
# 450000 케이스: 성공 - 13 / 실패 - 4
# 450000 케이스: 성공 - 14 / 실패 - 4
# 450000 케이스: 성공 - 15 / 실패 - 4
# 450000 케이스: 성공 - 16 / 실패 - 4
# 450000 케이스: 성공 - 17 / 실패 - 4
# 450000 케이스: 성공 - 18 / 실패 - 4
# 450000 케이스: 성공 - 19 / 실패 - 4
# 450000 케이스: 성공 - 19 / 실패 - 5
# 케이스 실패: 450000
# 460000 케이스: 성공 - 0 / 실패 - 1
# 460000 케이스: 성공 - 1 / 실패 - 1
# 460000 케이스: 성공 - 1 / 실패 - 2
# 460000 케이스: 성공 - 2 / 실패 - 2
# 460000 케이스: 성공 - 2 / 실패 - 3
# 460000 케이스: 성공 - 3 / 실패 - 3
# 460000 케이스: 성공 - 4 / 실패 - 3
# 460000 케이스: 성공 - 5 / 실패 - 3
# 460000 케이스: 성공 - 6 / 실패 - 3
# 460000 케이스: 성공 - 7 / 실패 - 3
# 460000 케이스: 성공 - 8 / 실패 - 3
# 460000 케이스: 성공 - 9 / 실패 - 3
# 460000 케이스: 성공 - 9 / 실패 - 4
# 460000 케이스: 성공 - 10 / 실패 - 4
# 460000 케이스: 성공 - 11 / 실패 - 4
# 460000 케이스: 성공 - 12 / 실패 - 4
# 460000 케이스: 성공 - 13 / 실패 - 4
# 460000 케이스: 성공 - 13 / 실패 - 5
# 케이스 실패: 460000
# 470000 케이스: 성공 - 1 / 실패 - 0
# 470000 케이스: 성공 - 1 / 실패 - 1
# 470000 케이스: 성공 - 2 / 실패 - 1
# 470000 케이스: 성공 - 3 / 실패 - 1
# 470000 케이스: 성공 - 3 / 실패 - 2
# 470000 케이스: 성공 - 4 / 실패 - 2
# 470000 케이스: 성공 - 5 / 실패 - 2
# 470000 케이스: 성공 - 6 / 실패 - 2
# 470000 케이스: 성공 - 6 / 실패 - 3
# 470000 케이스: 성공 - 7 / 실패 - 3
# 470000 케이스: 성공 - 7 / 실패 - 4
# 470000 케이스: 성공 - 8 / 실패 - 4
# 470000 케이스: 성공 - 9 / 실패 - 4
# 470000 케이스: 성공 - 9 / 실패 - 5
# 케이스 실패: 470000
# 480000 케이스: 성공 - 1 / 실패 - 0
# 480000 케이스: 성공 - 1 / 실패 - 1
# 480000 케이스: 성공 - 2 / 실패 - 1
# 480000 케이스: 성공 - 3 / 실패 - 1
# 480000 케이스: 성공 - 3 / 실패 - 2
# 480000 케이스: 성공 - 4 / 실패 - 2
# 480000 케이스: 성공 - 5 / 실패 - 2
# 480000 케이스: 성공 - 5 / 실패 - 3
# 480000 케이스: 성공 - 6 / 실패 - 3
# 480000 케이스: 성공 - 6 / 실패 - 4
# 480000 케이스: 성공 - 7 / 실패 - 4
# 480000 케이스: 성공 - 7 / 실패 - 5
# 케이스 실패: 480000
# 490000 케이스: 성공 - 1 / 실패 - 0
# 490000 케이스: 성공 - 2 / 실패 - 0
# 490000 케이스: 성공 - 3 / 실패 - 0
# 490000 케이스: 성공 - 4 / 실패 - 0
# 490000 케이스: 성공 - 5 / 실패 - 0
# 490000 케이스: 성공 - 6 / 실패 - 0
# 490000 케이스: 성공 - 6 / 실패 - 1
# 490000 케이스: 성공 - 7 / 실패 - 1
# 490000 케이스: 성공 - 8 / 실패 - 1
# 490000 케이스: 성공 - 9 / 실패 - 1
# 490000 케이스: 성공 - 10 / 실패 - 1
# 490000 케이스: 성공 - 11 / 실패 - 1
# 490000 케이스: 성공 - 12 / 실패 - 1
# 490000 케이스: 성공 - 13 / 실패 - 1
# 490000 케이스: 성공 - 13 / 실패 - 2
# 490000 케이스: 성공 - 13 / 실패 - 3
# 490000 케이스: 성공 - 14 / 실패 - 3
# 490000 케이스: 성공 - 14 / 실패 - 4
# 490000 케이스: 성공 - 15 / 실패 - 4
# 490000 케이스: 성공 - 16 / 실패 - 4
# 490000 케이스: 성공 - 17 / 실패 - 4
# 490000 케이스: 성공 - 18 / 실패 - 4
# 490000 케이스: 성공 - 19 / 실패 - 4
# 490000 케이스: 성공 - 20 / 실패 - 4
# 490000 케이스: 성공 - 21 / 실패 - 4
# 490000 케이스: 성공 - 21 / 실패 - 5
# 케이스 실패: 490000
# 500000 케이스: 성공 - 1 / 실패 - 0
# 500000 케이스: 성공 - 2 / 실패 - 0
# 500000 케이스: 성공 - 2 / 실패 - 1
# 500000 케이스: 성공 - 2 / 실패 - 2
# 500000 케이스: 성공 - 3 / 실패 - 2
# 500000 케이스: 성공 - 3 / 실패 - 3
# 500000 케이스: 성공 - 4 / 실패 - 3
# 500000 케이스: 성공 - 5 / 실패 - 3
# 500000 케이스: 성공 - 6 / 실패 - 3
# 500000 케이스: 성공 - 7 / 실패 - 3
# 500000 케이스: 성공 - 7 / 실패 - 4
# 500000 케이스: 성공 - 8 / 실패 - 4
# 500000 케이스: 성공 - 9 / 실패 - 4
# 500000 케이스: 성공 - 10 / 실패 - 4
# 500000 케이스: 성공 - 11 / 실패 - 4
# 500000 케이스: 성공 - 12 / 실패 - 4
# 500000 케이스: 성공 - 13 / 실패 - 4
# 500000 케이스: 성공 - 13 / 실패 - 5
# 케이스 실패: 500000
# 510000 케이스: 성공 - 0 / 실패 - 1
# 510000 케이스: 성공 - 1 / 실패 - 1
# 510000 케이스: 성공 - 2 / 실패 - 1
# 510000 케이스: 성공 - 3 / 실패 - 1
# 510000 케이스: 성공 - 4 / 실패 - 1
# 510000 케이스: 성공 - 5 / 실패 - 1
# 510000 케이스: 성공 - 5 / 실패 - 2
# 510000 케이스: 성공 - 6 / 실패 - 2
# 510000 케이스: 성공 - 7 / 실패 - 2
# 510000 케이스: 성공 - 8 / 실패 - 2
# 510000 케이스: 성공 - 8 / 실패 - 3
# 510000 케이스: 성공 - 9 / 실패 - 3
# 510000 케이스: 성공 - 10 / 실패 - 3
# 510000 케이스: 성공 - 11 / 실패 - 3
# 510000 케이스: 성공 - 11 / 실패 - 4
# 510000 케이스: 성공 - 12 / 실패 - 4
# 510000 케이스: 성공 - 13 / 실패 - 4
# 510000 케이스: 성공 - 14 / 실패 - 4
# 510000 케이스: 성공 - 15 / 실패 - 4
# 510000 케이스: 성공 - 16 / 실패 - 4
# 510000 케이스: 성공 - 17 / 실패 - 4
# 510000 케이스: 성공 - 17 / 실패 - 5
# 케이스 실패: 510000
# 520000 케이스: 성공 - 1 / 실패 - 0
# 520000 케이스: 성공 - 1 / 실패 - 1
# 520000 케이스: 성공 - 1 / 실패 - 2
# 520000 케이스: 성공 - 2 / 실패 - 2
# 520000 케이스: 성공 - 3 / 실패 - 2
# 520000 케이스: 성공 - 4 / 실패 - 2
# 520000 케이스: 성공 - 4 / 실패 - 3
# 520000 케이스: 성공 - 5 / 실패 - 3
# 520000 케이스: 성공 - 5 / 실패 - 4
# 520000 케이스: 성공 - 5 / 실패 - 5
# 케이스 실패: 520000
# 530000 케이스: 성공 - 1 / 실패 - 0
# 530000 케이스: 성공 - 2 / 실패 - 0
# 530000 케이스: 성공 - 3 / 실패 - 0
# 530000 케이스: 성공 - 3 / 실패 - 1
# 530000 케이스: 성공 - 4 / 실패 - 1
# 530000 케이스: 성공 - 5 / 실패 - 1
# 530000 케이스: 성공 - 6 / 실패 - 1
# 530000 케이스: 성공 - 7 / 실패 - 1
# 530000 케이스: 성공 - 8 / 실패 - 1
# 530000 케이스: 성공 - 8 / 실패 - 2
# 530000 케이스: 성공 - 9 / 실패 - 2
# 530000 케이스: 성공 - 9 / 실패 - 3
# 530000 케이스: 성공 - 9 / 실패 - 4
# 530000 케이스: 성공 - 10 / 실패 - 4
# 530000 케이스: 성공 - 11 / 실패 - 4
# 530000 케이스: 성공 - 12 / 실패 - 4
# 530000 케이스: 성공 - 13 / 실패 - 4
# 530000 케이스: 성공 - 13 / 실패 - 5
# 케이스 실패: 530000
# 540000 케이스: 성공 - 1 / 실패 - 0
# 540000 케이스: 성공 - 2 / 실패 - 0
# 540000 케이스: 성공 - 2 / 실패 - 1
# 540000 케이스: 성공 - 3 / 실패 - 1
# 540000 케이스: 성공 - 4 / 실패 - 1
# 540000 케이스: 성공 - 5 / 실패 - 1
# 540000 케이스: 성공 - 6 / 실패 - 1
# 540000 케이스: 성공 - 7 / 실패 - 1
# 540000 케이스: 성공 - 7 / 실패 - 2
# 540000 케이스: 성공 - 8 / 실패 - 2
# 540000 케이스: 성공 - 9 / 실패 - 2
# 540000 케이스: 성공 - 10 / 실패 - 2
# 540000 케이스: 성공 - 11 / 실패 - 2
# 540000 케이스: 성공 - 11 / 실패 - 3
# 540000 케이스: 성공 - 12 / 실패 - 3
# 540000 케이스: 성공 - 13 / 실패 - 3
# 540000 케이스: 성공 - 14 / 실패 - 3
# 540000 케이스: 성공 - 15 / 실패 - 3
# 540000 케이스: 성공 - 16 / 실패 - 3
# 540000 케이스: 성공 - 17 / 실패 - 3
# 540000 케이스: 성공 - 17 / 실패 - 4
# 540000 케이스: 성공 - 18 / 실패 - 4
# 540000 케이스: 성공 - 19 / 실패 - 4
# 540000 케이스: 성공 - 20 / 실패 - 4
# 540000 케이스: 성공 - 21 / 실패 - 4
# 540000 케이스: 성공 - 21 / 실패 - 5
# 케이스 실패: 540000
# 550000 케이스: 성공 - 1 / 실패 - 0
# 550000 케이스: 성공 - 2 / 실패 - 0
# 550000 케이스: 성공 - 2 / 실패 - 1
# 550000 케이스: 성공 - 3 / 실패 - 1
# 550000 케이스: 성공 - 4 / 실패 - 1
# 550000 케이스: 성공 - 5 / 실패 - 1
# 550000 케이스: 성공 - 6 / 실패 - 1
# 550000 케이스: 성공 - 7 / 실패 - 1
# 550000 케이스: 성공 - 8 / 실패 - 1
# 550000 케이스: 성공 - 9 / 실패 - 1
# 550000 케이스: 성공 - 10 / 실패 - 1
# 550000 케이스: 성공 - 11 / 실패 - 1
# 550000 케이스: 성공 - 11 / 실패 - 2
# 550000 케이스: 성공 - 11 / 실패 - 3
# 550000 케이스: 성공 - 11 / 실패 - 4
# 550000 케이스: 성공 - 12 / 실패 - 4
# 550000 케이스: 성공 - 13 / 실패 - 4
# 550000 케이스: 성공 - 13 / 실패 - 5
# 케이스 실패: 550000
# 560000 케이스: 성공 - 0 / 실패 - 1
# 560000 케이스: 성공 - 1 / 실패 - 1
# 560000 케이스: 성공 - 2 / 실패 - 1
# 560000 케이스: 성공 - 2 / 실패 - 2
# 560000 케이스: 성공 - 3 / 실패 - 2
# 560000 케이스: 성공 - 4 / 실패 - 2
# 560000 케이스: 성공 - 5 / 실패 - 2
# 560000 케이스: 성공 - 5 / 실패 - 3
# 560000 케이스: 성공 - 5 / 실패 - 4
# 560000 케이스: 성공 - 6 / 실패 - 4
# 560000 케이스: 성공 - 7 / 실패 - 4
# 560000 케이스: 성공 - 7 / 실패 - 5
# 케이스 실패: 560000
# 570000 케이스: 성공 - 1 / 실패 - 0
# 570000 케이스: 성공 - 2 / 실패 - 0
# 570000 케이스: 성공 - 3 / 실패 - 0
# 570000 케이스: 성공 - 4 / 실패 - 0
# 570000 케이스: 성공 - 5 / 실패 - 0
# 570000 케이스: 성공 - 5 / 실패 - 1
# 570000 케이스: 성공 - 6 / 실패 - 1
# 570000 케이스: 성공 - 6 / 실패 - 2
# 570000 케이스: 성공 - 7 / 실패 - 2
# 570000 케이스: 성공 - 8 / 실패 - 2
# 570000 케이스: 성공 - 9 / 실패 - 2
# 570000 케이스: 성공 - 10 / 실패 - 2
# 570000 케이스: 성공 - 11 / 실패 - 2
# 570000 케이스: 성공 - 11 / 실패 - 3
# 570000 케이스: 성공 - 12 / 실패 - 3
# 570000 케이스: 성공 - 13 / 실패 - 3
# 570000 케이스: 성공 - 13 / 실패 - 4
# 570000 케이스: 성공 - 14 / 실패 - 4
# 570000 케이스: 성공 - 15 / 실패 - 4
# 570000 케이스: 성공 - 16 / 실패 - 4
# 570000 케이스: 성공 - 17 / 실패 - 4
# 570000 케이스: 성공 - 18 / 실패 - 4
# 570000 케이스: 성공 - 19 / 실패 - 4
# 570000 케이스: 성공 - 20 / 실패 - 4
# 570000 케이스: 성공 - 21 / 실패 - 4
# 570000 케이스: 성공 - 22 / 실패 - 4
# 570000 케이스: 성공 - 23 / 실패 - 4
# 570000 케이스: 성공 - 24 / 실패 - 4
# 570000 케이스: 성공 - 25 / 실패 - 4
# 570000 케이스: 성공 - 26 / 실패 - 4
# 570000 케이스: 성공 - 27 / 실패 - 4
# 570000 케이스: 성공 - 28 / 실패 - 4
# 570000 케이스: 성공 - 29 / 실패 - 4
# 570000 케이스: 성공 - 30 / 실패 - 4
# 570000 케이스: 성공 - 31 / 실패 - 4
# 570000 케이스: 성공 - 31 / 실패 - 5
# 케이스 실패: 570000
# 580000 케이스: 성공 - 1 / 실패 - 0
# 580000 케이스: 성공 - 2 / 실패 - 0
# 580000 케이스: 성공 - 3 / 실패 - 0
# 580000 케이스: 성공 - 4 / 실패 - 0
# 580000 케이스: 성공 - 4 / 실패 - 1
# 580000 케이스: 성공 - 5 / 실패 - 1
# 580000 케이스: 성공 - 6 / 실패 - 1
# 580000 케이스: 성공 - 6 / 실패 - 2
# 580000 케이스: 성공 - 6 / 실패 - 3
# 580000 케이스: 성공 - 7 / 실패 - 3
# 580000 케이스: 성공 - 8 / 실패 - 3
# 580000 케이스: 성공 - 9 / 실패 - 3
# 580000 케이스: 성공 - 10 / 실패 - 3
# 580000 케이스: 성공 - 10 / 실패 - 4
# 580000 케이스: 성공 - 11 / 실패 - 4
# 580000 케이스: 성공 - 12 / 실패 - 4
# 580000 케이스: 성공 - 13 / 실패 - 4
# 580000 케이스: 성공 - 13 / 실패 - 5
# 케이스 실패: 580000
# 590000 케이스: 성공 - 1 / 실패 - 0
# 590000 케이스: 성공 - 2 / 실패 - 0
# 590000 케이스: 성공 - 3 / 실패 - 0
# 590000 케이스: 성공 - 4 / 실패 - 0
# 590000 케이스: 성공 - 5 / 실패 - 0
# 590000 케이스: 성공 - 6 / 실패 - 0
# 590000 케이스: 성공 - 6 / 실패 - 1
# 590000 케이스: 성공 - 7 / 실패 - 1
# 590000 케이스: 성공 - 8 / 실패 - 1
# 590000 케이스: 성공 - 8 / 실패 - 2
# 590000 케이스: 성공 - 9 / 실패 - 2
# 590000 케이스: 성공 - 10 / 실패 - 2
# 590000 케이스: 성공 - 11 / 실패 - 2
# 590000 케이스: 성공 - 12 / 실패 - 2
# 590000 케이스: 성공 - 13 / 실패 - 2
# 590000 케이스: 성공 - 14 / 실패 - 2
# 590000 케이스: 성공 - 15 / 실패 - 2
# 590000 케이스: 성공 - 16 / 실패 - 2
# 590000 케이스: 성공 - 17 / 실패 - 2
# 590000 케이스: 성공 - 18 / 실패 - 2
# 590000 케이스: 성공 - 18 / 실패 - 3
# 590000 케이스: 성공 - 19 / 실패 - 3
# 590000 케이스: 성공 - 20 / 실패 - 3
# 590000 케이스: 성공 - 21 / 실패 - 3
# 590000 케이스: 성공 - 21 / 실패 - 4
# 590000 케이스: 성공 - 21 / 실패 - 5
# 케이스 실패: 590000
# 600000 케이스: 성공 - 0 / 실패 - 1
# 600000 케이스: 성공 - 0 / 실패 - 2
# 600000 케이스: 성공 - 1 / 실패 - 2
# 600000 케이스: 성공 - 1 / 실패 - 3
# 600000 케이스: 성공 - 2 / 실패 - 3
# 600000 케이스: 성공 - 2 / 실패 - 4
# 600000 케이스: 성공 - 3 / 실패 - 4
# 600000 케이스: 성공 - 3 / 실패 - 5
# 케이스 실패: 600000
# 610000 케이스: 성공 - 1 / 실패 - 0
# 610000 케이스: 성공 - 2 / 실패 - 0
# 610000 케이스: 성공 - 3 / 실패 - 0
# 610000 케이스: 성공 - 4 / 실패 - 0
# 610000 케이스: 성공 - 5 / 실패 - 0
# 610000 케이스: 성공 - 6 / 실패 - 0
# 610000 케이스: 성공 - 7 / 실패 - 0
# 610000 케이스: 성공 - 8 / 실패 - 0
# 610000 케이스: 성공 - 8 / 실패 - 1
# 610000 케이스: 성공 - 9 / 실패 - 1
# 610000 케이스: 성공 - 10 / 실패 - 1
# 610000 케이스: 성공 - 11 / 실패 - 1
# 610000 케이스: 성공 - 11 / 실패 - 2
# 610000 케이스: 성공 - 12 / 실패 - 2
# 610000 케이스: 성공 - 13 / 실패 - 2
# 610000 케이스: 성공 - 14 / 실패 - 2
# 610000 케이스: 성공 - 14 / 실패 - 3
# 610000 케이스: 성공 - 15 / 실패 - 3
# 610000 케이스: 성공 - 16 / 실패 - 3
# 610000 케이스: 성공 - 16 / 실패 - 4
# 610000 케이스: 성공 - 17 / 실패 - 4
# 610000 케이스: 성공 - 18 / 실패 - 4
# 610000 케이스: 성공 - 19 / 실패 - 4
# 610000 케이스: 성공 - 20 / 실패 - 4
# 610000 케이스: 성공 - 21 / 실패 - 4
# 610000 케이스: 성공 - 22 / 실패 - 4
# 610000 케이스: 성공 - 23 / 실패 - 4
# 610000 케이스: 성공 - 24 / 실패 - 4
# 610000 케이스: 성공 - 25 / 실패 - 4
# 610000 케이스: 성공 - 26 / 실패 - 4
# 610000 케이스: 성공 - 27 / 실패 - 4
# 610000 케이스: 성공 - 27 / 실패 - 5
# 케이스 실패: 610000
# 620000 케이스: 성공 - 1 / 실패 - 0
# 620000 케이스: 성공 - 2 / 실패 - 0
# 620000 케이스: 성공 - 3 / 실패 - 0
# 620000 케이스: 성공 - 3 / 실패 - 1
# 620000 케이스: 성공 - 4 / 실패 - 1
# 620000 케이스: 성공 - 4 / 실패 - 2
# 620000 케이스: 성공 - 5 / 실패 - 2
# 620000 케이스: 성공 - 5 / 실패 - 3
# 620000 케이스: 성공 - 5 / 실패 - 4
# 620000 케이스: 성공 - 6 / 실패 - 4
# 620000 케이스: 성공 - 6 / 실패 - 5
# 케이스 실패: 620000
# 630000 케이스: 성공 - 0 / 실패 - 1
# 630000 케이스: 성공 - 1 / 실패 - 1
# 630000 케이스: 성공 - 2 / 실패 - 1
# 630000 케이스: 성공 - 3 / 실패 - 1
# 630000 케이스: 성공 - 4 / 실패 - 1
# 630000 케이스: 성공 - 4 / 실패 - 2
# 630000 케이스: 성공 - 4 / 실패 - 3
# 630000 케이스: 성공 - 5 / 실패 - 3
# 630000 케이스: 성공 - 5 / 실패 - 4
# 630000 케이스: 성공 - 6 / 실패 - 4
# 630000 케이스: 성공 - 6 / 실패 - 5
# 케이스 실패: 630000
# 640000 케이스: 성공 - 1 / 실패 - 0
# 640000 케이스: 성공 - 2 / 실패 - 0
# 640000 케이스: 성공 - 3 / 실패 - 0
# 640000 케이스: 성공 - 4 / 실패 - 0
# 640000 케이스: 성공 - 4 / 실패 - 1
# 640000 케이스: 성공 - 4 / 실패 - 2
# 640000 케이스: 성공 - 5 / 실패 - 2
# 640000 케이스: 성공 - 6 / 실패 - 2
# 640000 케이스: 성공 - 6 / 실패 - 3
# 640000 케이스: 성공 - 6 / 실패 - 4
# 640000 케이스: 성공 - 7 / 실패 - 4
# 640000 케이스: 성공 - 8 / 실패 - 4
# 640000 케이스: 성공 - 9 / 실패 - 4
# 640000 케이스: 성공 - 10 / 실패 - 4
# 640000 케이스: 성공 - 10 / 실패 - 5
# 케이스 실패: 640000
# 650000 케이스: 성공 - 1 / 실패 - 0
# 650000 케이스: 성공 - 2 / 실패 - 0
# 650000 케이스: 성공 - 3 / 실패 - 0
# 650000 케이스: 성공 - 4 / 실패 - 0
# 650000 케이스: 성공 - 5 / 실패 - 0
# 650000 케이스: 성공 - 6 / 실패 - 0
# 650000 케이스: 성공 - 6 / 실패 - 1
# 650000 케이스: 성공 - 7 / 실패 - 1
# 650000 케이스: 성공 - 7 / 실패 - 2
# 650000 케이스: 성공 - 7 / 실패 - 3
# 650000 케이스: 성공 - 8 / 실패 - 3
# 650000 케이스: 성공 - 9 / 실패 - 3
# 650000 케이스: 성공 - 10 / 실패 - 3
# 650000 케이스: 성공 - 11 / 실패 - 3
# 650000 케이스: 성공 - 12 / 실패 - 3
# 650000 케이스: 성공 - 13 / 실패 - 3
# 650000 케이스: 성공 - 13 / 실패 - 4
# 650000 케이스: 성공 - 14 / 실패 - 4
# 650000 케이스: 성공 - 15 / 실패 - 4
# 650000 케이스: 성공 - 16 / 실패 - 4
# 650000 케이스: 성공 - 17 / 실패 - 4
# 650000 케이스: 성공 - 18 / 실패 - 4
# 650000 케이스: 성공 - 19 / 실패 - 4
# 650000 케이스: 성공 - 20 / 실패 - 4
# 650000 케이스: 성공 - 21 / 실패 - 4
# 650000 케이스: 성공 - 22 / 실패 - 4
# 650000 케이스: 성공 - 23 / 실패 - 4
# 650000 케이스: 성공 - 24 / 실패 - 4
# 650000 케이스: 성공 - 24 / 실패 - 5
# 케이스 실패: 650000
# 660000 케이스: 성공 - 1 / 실패 - 0
# 660000 케이스: 성공 - 2 / 실패 - 0
# 660000 케이스: 성공 - 3 / 실패 - 0
# 660000 케이스: 성공 - 4 / 실패 - 0
# 660000 케이스: 성공 - 4 / 실패 - 1
# 660000 케이스: 성공 - 5 / 실패 - 1
# 660000 케이스: 성공 - 6 / 실패 - 1
# 660000 케이스: 성공 - 7 / 실패 - 1
# 660000 케이스: 성공 - 8 / 실패 - 1
# 660000 케이스: 성공 - 8 / 실패 - 2
# 660000 케이스: 성공 - 9 / 실패 - 2
# 660000 케이스: 성공 - 10 / 실패 - 2
# 660000 케이스: 성공 - 11 / 실패 - 2
# 660000 케이스: 성공 - 12 / 실패 - 2
# 660000 케이스: 성공 - 13 / 실패 - 2
# 660000 케이스: 성공 - 14 / 실패 - 2
# 660000 케이스: 성공 - 15 / 실패 - 2
# 660000 케이스: 성공 - 16 / 실패 - 2
# 660000 케이스: 성공 - 17 / 실패 - 2
# 660000 케이스: 성공 - 18 / 실패 - 2
# 660000 케이스: 성공 - 19 / 실패 - 2
# 660000 케이스: 성공 - 20 / 실패 - 2
# 660000 케이스: 성공 - 21 / 실패 - 2
# 660000 케이스: 성공 - 22 / 실패 - 2
# 660000 케이스: 성공 - 23 / 실패 - 2
# 660000 케이스: 성공 - 24 / 실패 - 2
# 660000 케이스: 성공 - 25 / 실패 - 2
# 660000 케이스: 성공 - 26 / 실패 - 2
# 660000 케이스: 성공 - 27 / 실패 - 2
# 660000 케이스: 성공 - 28 / 실패 - 2
# 660000 케이스: 성공 - 29 / 실패 - 2
# 660000 케이스: 성공 - 30 / 실패 - 2
# 660000 케이스: 성공 - 30 / 실패 - 3
# 660000 케이스: 성공 - 31 / 실패 - 3
# 660000 케이스: 성공 - 32 / 실패 - 3
# 660000 케이스: 성공 - 33 / 실패 - 3
# 660000 케이스: 성공 - 34 / 실패 - 3
# 660000 케이스: 성공 - 34 / 실패 - 4
# 660000 케이스: 성공 - 35 / 실패 - 4
# 660000 케이스: 성공 - 36 / 실패 - 4
# 660000 케이스: 성공 - 37 / 실패 - 4
# 660000 케이스: 성공 - 38 / 실패 - 4
# 660000 케이스: 성공 - 39 / 실패 - 4
# 660000 케이스: 성공 - 40 / 실패 - 4
# 660000 케이스: 성공 - 41 / 실패 - 4
# 660000 케이스: 성공 - 42 / 실패 - 4
# 660000 케이스: 성공 - 43 / 실패 - 4
# 660000 케이스: 성공 - 44 / 실패 - 4
# 660000 케이스: 성공 - 45 / 실패 - 4
# 660000 케이스: 성공 - 46 / 실패 - 4
# 660000 케이스: 성공 - 47 / 실패 - 4
# 660000 케이스: 성공 - 48 / 실패 - 4
# 660000 케이스: 성공 - 49 / 실패 - 4
# 660000 케이스: 성공 - 50 / 실패 - 4
# 660000 케이스: 성공 - 50 / 실패 - 5
# 케이스 실패: 660000
# 670000 케이스: 성공 - 0 / 실패 - 1
# 670000 케이스: 성공 - 1 / 실패 - 1
# 670000 케이스: 성공 - 2 / 실패 - 1
# 670000 케이스: 성공 - 2 / 실패 - 2
# 670000 케이스: 성공 - 3 / 실패 - 2
# 670000 케이스: 성공 - 4 / 실패 - 2
# 670000 케이스: 성공 - 5 / 실패 - 2
# 670000 케이스: 성공 - 6 / 실패 - 2
# 670000 케이스: 성공 - 7 / 실패 - 2
# 670000 케이스: 성공 - 8 / 실패 - 2
# 670000 케이스: 성공 - 9 / 실패 - 2
# 670000 케이스: 성공 - 9 / 실패 - 3
# 670000 케이스: 성공 - 9 / 실패 - 4
# 670000 케이스: 성공 - 10 / 실패 - 4
# 670000 케이스: 성공 - 11 / 실패 - 4
# 670000 케이스: 성공 - 12 / 실패 - 4
# 670000 케이스: 성공 - 13 / 실패 - 4
# 670000 케이스: 성공 - 14 / 실패 - 4
# 670000 케이스: 성공 - 15 / 실패 - 4
# 670000 케이스: 성공 - 16 / 실패 - 4
# 670000 케이스: 성공 - 17 / 실패 - 4
# 670000 케이스: 성공 - 18 / 실패 - 4
# 670000 케이스: 성공 - 18 / 실패 - 5
# 케이스 실패: 670000
# 680000 케이스: 성공 - 1 / 실패 - 0
# 680000 케이스: 성공 - 1 / 실패 - 1
# 680000 케이스: 성공 - 2 / 실패 - 1
# 680000 케이스: 성공 - 3 / 실패 - 1
# 680000 케이스: 성공 - 3 / 실패 - 2
# 680000 케이스: 성공 - 4 / 실패 - 2
# 680000 케이스: 성공 - 4 / 실패 - 3
# 680000 케이스: 성공 - 4 / 실패 - 4
# 680000 케이스: 성공 - 5 / 실패 - 4
# 680000 케이스: 성공 - 6 / 실패 - 4
# 680000 케이스: 성공 - 7 / 실패 - 4
# 680000 케이스: 성공 - 8 / 실패 - 4
# 680000 케이스: 성공 - 9 / 실패 - 4
# 680000 케이스: 성공 - 10 / 실패 - 4
# 680000 케이스: 성공 - 11 / 실패 - 4
# 680000 케이스: 성공 - 12 / 실패 - 4
# 680000 케이스: 성공 - 13 / 실패 - 4
# 680000 케이스: 성공 - 14 / 실패 - 4
# 680000 케이스: 성공 - 14 / 실패 - 5
# 케이스 실패: 680000
# 690000 케이스: 성공 - 1 / 실패 - 0
# 690000 케이스: 성공 - 2 / 실패 - 0
# 690000 케이스: 성공 - 3 / 실패 - 0
# 690000 케이스: 성공 - 4 / 실패 - 0
# 690000 케이스: 성공 - 5 / 실패 - 0
# 690000 케이스: 성공 - 6 / 실패 - 0
# 690000 케이스: 성공 - 7 / 실패 - 0
# 690000 케이스: 성공 - 8 / 실패 - 0
# 690000 케이스: 성공 - 9 / 실패 - 0
# 690000 케이스: 성공 - 9 / 실패 - 1
# 690000 케이스: 성공 - 10 / 실패 - 1
# 690000 케이스: 성공 - 11 / 실패 - 1
# 690000 케이스: 성공 - 12 / 실패 - 1
# 690000 케이스: 성공 - 12 / 실패 - 2
# 690000 케이스: 성공 - 13 / 실패 - 2
# 690000 케이스: 성공 - 14 / 실패 - 2
# 690000 케이스: 성공 - 15 / 실패 - 2
# 690000 케이스: 성공 - 16 / 실패 - 2
# 690000 케이스: 성공 - 17 / 실패 - 2
# 690000 케이스: 성공 - 18 / 실패 - 2
# 690000 케이스: 성공 - 19 / 실패 - 2
# 690000 케이스: 성공 - 20 / 실패 - 2
# 690000 케이스: 성공 - 21 / 실패 - 2
# 690000 케이스: 성공 - 22 / 실패 - 2
# 690000 케이스: 성공 - 22 / 실패 - 3
# 690000 케이스: 성공 - 23 / 실패 - 3
# 690000 케이스: 성공 - 24 / 실패 - 3
# 690000 케이스: 성공 - 25 / 실패 - 3
# 690000 케이스: 성공 - 26 / 실패 - 3
# 690000 케이스: 성공 - 27 / 실패 - 3
# 690000 케이스: 성공 - 28 / 실패 - 3
# 690000 케이스: 성공 - 28 / 실패 - 4
# 690000 케이스: 성공 - 29 / 실패 - 4
# 690000 케이스: 성공 - 30 / 실패 - 4
# 690000 케이스: 성공 - 31 / 실패 - 4
# 690000 케이스: 성공 - 32 / 실패 - 4
# 690000 케이스: 성공 - 33 / 실패 - 4
# 690000 케이스: 성공 - 34 / 실패 - 4
# 690000 케이스: 성공 - 35 / 실패 - 4
# 690000 케이스: 성공 - 36 / 실패 - 4
# 690000 케이스: 성공 - 37 / 실패 - 4
# 690000 케이스: 성공 - 38 / 실패 - 4
# 690000 케이스: 성공 - 39 / 실패 - 4
# 690000 케이스: 성공 - 40 / 실패 - 4
# 690000 케이스: 성공 - 41 / 실패 - 4
# 690000 케이스: 성공 - 42 / 실패 - 4
# 690000 케이스: 성공 - 43 / 실패 - 4
# 690000 케이스: 성공 - 44 / 실패 - 4
# 690000 케이스: 성공 - 45 / 실패 - 4
# 690000 케이스: 성공 - 46 / 실패 - 4
# 690000 케이스: 성공 - 47 / 실패 - 4
# 690000 케이스: 성공 - 47 / 실패 - 5
# 케이스 실패: 690000
# 700000 케이스: 성공 - 0 / 실패 - 1
# 700000 케이스: 성공 - 1 / 실패 - 1
# 700000 케이스: 성공 - 2 / 실패 - 1
# 700000 케이스: 성공 - 3 / 실패 - 1
# 700000 케이스: 성공 - 3 / 실패 - 2
# 700000 케이스: 성공 - 4 / 실패 - 2
# 700000 케이스: 성공 - 5 / 실패 - 2
# 700000 케이스: 성공 - 6 / 실패 - 2
# 700000 케이스: 성공 - 7 / 실패 - 2
# 700000 케이스: 성공 - 8 / 실패 - 2
# 700000 케이스: 성공 - 9 / 실패 - 2
# 700000 케이스: 성공 - 10 / 실패 - 2
# 700000 케이스: 성공 - 11 / 실패 - 2
# 700000 케이스: 성공 - 12 / 실패 - 2
# 700000 케이스: 성공 - 13 / 실패 - 2
# 700000 케이스: 성공 - 13 / 실패 - 3
# 700000 케이스: 성공 - 14 / 실패 - 3
# 700000 케이스: 성공 - 15 / 실패 - 3
# 700000 케이스: 성공 - 16 / 실패 - 3
# 700000 케이스: 성공 - 17 / 실패 - 3
# 700000 케이스: 성공 - 18 / 실패 - 3
# 700000 케이스: 성공 - 19 / 실패 - 3
# 700000 케이스: 성공 - 20 / 실패 - 3
# 700000 케이스: 성공 - 20 / 실패 - 4
# 700000 케이스: 성공 - 21 / 실패 - 4
# 700000 케이스: 성공 - 22 / 실패 - 4
# 700000 케이스: 성공 - 23 / 실패 - 4
# 700000 케이스: 성공 - 24 / 실패 - 4
# 700000 케이스: 성공 - 25 / 실패 - 4
# 700000 케이스: 성공 - 26 / 실패 - 4
# 700000 케이스: 성공 - 27 / 실패 - 4
# 700000 케이스: 성공 - 28 / 실패 - 4
# 700000 케이스: 성공 - 29 / 실패 - 4
# 700000 케이스: 성공 - 29 / 실패 - 5
# 케이스 실패: 700000
# 710000 케이스: 성공 - 1 / 실패 - 0
# 710000 케이스: 성공 - 2 / 실패 - 0
# 710000 케이스: 성공 - 3 / 실패 - 0
# 710000 케이스: 성공 - 4 / 실패 - 0
# 710000 케이스: 성공 - 4 / 실패 - 1
# 710000 케이스: 성공 - 5 / 실패 - 1
# 710000 케이스: 성공 - 5 / 실패 - 2
# 710000 케이스: 성공 - 5 / 실패 - 3
# 710000 케이스: 성공 - 6 / 실패 - 3
# 710000 케이스: 성공 - 7 / 실패 - 3
# 710000 케이스: 성공 - 8 / 실패 - 3
# 710000 케이스: 성공 - 9 / 실패 - 3
# 710000 케이스: 성공 - 10 / 실패 - 3
# 710000 케이스: 성공 - 11 / 실패 - 3
# 710000 케이스: 성공 - 12 / 실패 - 3
# 710000 케이스: 성공 - 13 / 실패 - 3
# 710000 케이스: 성공 - 14 / 실패 - 3
# 710000 케이스: 성공 - 15 / 실패 - 3
# 710000 케이스: 성공 - 15 / 실패 - 4
# 710000 케이스: 성공 - 16 / 실패 - 4
# 710000 케이스: 성공 - 17 / 실패 - 4
# 710000 케이스: 성공 - 18 / 실패 - 4
# 710000 케이스: 성공 - 19 / 실패 - 4
# 710000 케이스: 성공 - 20 / 실패 - 4
# 710000 케이스: 성공 - 21 / 실패 - 4
# 710000 케이스: 성공 - 22 / 실패 - 4
# 710000 케이스: 성공 - 22 / 실패 - 5
# 케이스 실패: 710000
# 720000 케이스: 성공 - 1 / 실패 - 0
# 720000 케이스: 성공 - 2 / 실패 - 0
# 720000 케이스: 성공 - 3 / 실패 - 0
# 720000 케이스: 성공 - 4 / 실패 - 0
# 720000 케이스: 성공 - 5 / 실패 - 0
# 720000 케이스: 성공 - 5 / 실패 - 1
# 720000 케이스: 성공 - 6 / 실패 - 1
# 720000 케이스: 성공 - 7 / 실패 - 1
# 720000 케이스: 성공 - 8 / 실패 - 1
# 720000 케이스: 성공 - 9 / 실패 - 1
# 720000 케이스: 성공 - 9 / 실패 - 2
# 720000 케이스: 성공 - 10 / 실패 - 2
# 720000 케이스: 성공 - 11 / 실패 - 2
# 720000 케이스: 성공 - 12 / 실패 - 2
# 720000 케이스: 성공 - 12 / 실패 - 3
# 720000 케이스: 성공 - 13 / 실패 - 3
# 720000 케이스: 성공 - 14 / 실패 - 3
# 720000 케이스: 성공 - 15 / 실패 - 3
# 720000 케이스: 성공 - 15 / 실패 - 4
# 720000 케이스: 성공 - 15 / 실패 - 5
# 케이스 실패: 720000
# 730000 케이스: 성공 - 1 / 실패 - 0
# 730000 케이스: 성공 - 2 / 실패 - 0
# 730000 케이스: 성공 - 3 / 실패 - 0
# 730000 케이스: 성공 - 3 / 실패 - 1
# 730000 케이스: 성공 - 3 / 실패 - 2
# 730000 케이스: 성공 - 4 / 실패 - 2
# 730000 케이스: 성공 - 5 / 실패 - 2
# 730000 케이스: 성공 - 6 / 실패 - 2
# 730000 케이스: 성공 - 6 / 실패 - 3
# 730000 케이스: 성공 - 7 / 실패 - 3
# 730000 케이스: 성공 - 8 / 실패 - 3
# 730000 케이스: 성공 - 9 / 실패 - 3
# 730000 케이스: 성공 - 10 / 실패 - 3
# 730000 케이스: 성공 - 10 / 실패 - 4
# 730000 케이스: 성공 - 11 / 실패 - 4
# 730000 케이스: 성공 - 12 / 실패 - 4
# 730000 케이스: 성공 - 13 / 실패 - 4
# 730000 케이스: 성공 - 14 / 실패 - 4
# 730000 케이스: 성공 - 14 / 실패 - 5
# 케이스 실패: 730000
# 740000 케이스: 성공 - 1 / 실패 - 0
# 740000 케이스: 성공 - 2 / 실패 - 0
# 740000 케이스: 성공 - 2 / 실패 - 1
# 740000 케이스: 성공 - 3 / 실패 - 1
# 740000 케이스: 성공 - 4 / 실패 - 1
# 740000 케이스: 성공 - 5 / 실패 - 1
# 740000 케이스: 성공 - 6 / 실패 - 1
# 740000 케이스: 성공 - 7 / 실패 - 1
# 740000 케이스: 성공 - 8 / 실패 - 1
# 740000 케이스: 성공 - 8 / 실패 - 2
# 740000 케이스: 성공 - 9 / 실패 - 2
# 740000 케이스: 성공 - 10 / 실패 - 2
# 740000 케이스: 성공 - 11 / 실패 - 2
# 740000 케이스: 성공 - 12 / 실패 - 2
# 740000 케이스: 성공 - 13 / 실패 - 2
# 740000 케이스: 성공 - 14 / 실패 - 2
# 740000 케이스: 성공 - 14 / 실패 - 3
# 740000 케이스: 성공 - 14 / 실패 - 4
# 740000 케이스: 성공 - 15 / 실패 - 4
# 740000 케이스: 성공 - 16 / 실패 - 4
# 740000 케이스: 성공 - 17 / 실패 - 4
# 740000 케이스: 성공 - 18 / 실패 - 4
# 740000 케이스: 성공 - 19 / 실패 - 4
# 740000 케이스: 성공 - 20 / 실패 - 4
# 740000 케이스: 성공 - 21 / 실패 - 4
# 740000 케이스: 성공 - 22 / 실패 - 4
# 740000 케이스: 성공 - 23 / 실패 - 4
# 740000 케이스: 성공 - 24 / 실패 - 4
# 740000 케이스: 성공 - 25 / 실패 - 4
# 740000 케이스: 성공 - 26 / 실패 - 4
# 740000 케이스: 성공 - 26 / 실패 - 5
# 케이스 실패: 740000
# 750000 케이스: 성공 - 1 / 실패 - 0
# 750000 케이스: 성공 - 2 / 실패 - 0
# 750000 케이스: 성공 - 2 / 실패 - 1
# 750000 케이스: 성공 - 3 / 실패 - 1
# 750000 케이스: 성공 - 3 / 실패 - 2
# 750000 케이스: 성공 - 4 / 실패 - 2
# 750000 케이스: 성공 - 5 / 실패 - 2
# 750000 케이스: 성공 - 5 / 실패 - 3
# 750000 케이스: 성공 - 6 / 실패 - 3
# 750000 케이스: 성공 - 7 / 실패 - 3
# 750000 케이스: 성공 - 8 / 실패 - 3
# 750000 케이스: 성공 - 9 / 실패 - 3
# 750000 케이스: 성공 - 10 / 실패 - 3
# 750000 케이스: 성공 - 11 / 실패 - 3
# 750000 케이스: 성공 - 11 / 실패 - 4
# 750000 케이스: 성공 - 11 / 실패 - 5
# 케이스 실패: 750000
# 760000 케이스: 성공 - 0 / 실패 - 1
# 760000 케이스: 성공 - 1 / 실패 - 1
# 760000 케이스: 성공 - 2 / 실패 - 1
# 760000 케이스: 성공 - 3 / 실패 - 1
# 760000 케이스: 성공 - 4 / 실패 - 1
# 760000 케이스: 성공 - 4 / 실패 - 2
# 760000 케이스: 성공 - 5 / 실패 - 2
# 760000 케이스: 성공 - 6 / 실패 - 2
# 760000 케이스: 성공 - 7 / 실패 - 2
# 760000 케이스: 성공 - 8 / 실패 - 2
# 760000 케이스: 성공 - 9 / 실패 - 2
# 760000 케이스: 성공 - 10 / 실패 - 2
# 760000 케이스: 성공 - 11 / 실패 - 2
# 760000 케이스: 성공 - 12 / 실패 - 2
# 760000 케이스: 성공 - 12 / 실패 - 3
# 760000 케이스: 성공 - 13 / 실패 - 3
# 760000 케이스: 성공 - 13 / 실패 - 4
# 760000 케이스: 성공 - 14 / 실패 - 4
# 760000 케이스: 성공 - 15 / 실패 - 4
# 760000 케이스: 성공 - 16 / 실패 - 4
# 760000 케이스: 성공 - 17 / 실패 - 4
# 760000 케이스: 성공 - 18 / 실패 - 4
# 760000 케이스: 성공 - 18 / 실패 - 5
# 케이스 실패: 760000
# 770000 케이스: 성공 - 0 / 실패 - 1
# 770000 케이스: 성공 - 0 / 실패 - 2
# 770000 케이스: 성공 - 1 / 실패 - 2
# 770000 케이스: 성공 - 2 / 실패 - 2
# 770000 케이스: 성공 - 3 / 실패 - 2
# 770000 케이스: 성공 - 4 / 실패 - 2
# 770000 케이스: 성공 - 4 / 실패 - 3
# 770000 케이스: 성공 - 5 / 실패 - 3
# 770000 케이스: 성공 - 6 / 실패 - 3
# 770000 케이스: 성공 - 6 / 실패 - 4
# 770000 케이스: 성공 - 7 / 실패 - 4
# 770000 케이스: 성공 - 8 / 실패 - 4
# 770000 케이스: 성공 - 9 / 실패 - 4
# 770000 케이스: 성공 - 9 / 실패 - 5
# 케이스 실패: 770000
# 780000 케이스: 성공 - 1 / 실패 - 0
# 780000 케이스: 성공 - 2 / 실패 - 0
# 780000 케이스: 성공 - 3 / 실패 - 0
# 780000 케이스: 성공 - 4 / 실패 - 0
# 780000 케이스: 성공 - 5 / 실패 - 0
# 780000 케이스: 성공 - 6 / 실패 - 0
# 780000 케이스: 성공 - 6 / 실패 - 1
# 780000 케이스: 성공 - 7 / 실패 - 1
# 780000 케이스: 성공 - 8 / 실패 - 1
# 780000 케이스: 성공 - 9 / 실패 - 1
# 780000 케이스: 성공 - 10 / 실패 - 1
# 780000 케이스: 성공 - 11 / 실패 - 1
# 780000 케이스: 성공 - 12 / 실패 - 1
# 780000 케이스: 성공 - 13 / 실패 - 1
# 780000 케이스: 성공 - 14 / 실패 - 1
# 780000 케이스: 성공 - 15 / 실패 - 1
# 780000 케이스: 성공 - 16 / 실패 - 1
# 780000 케이스: 성공 - 17 / 실패 - 1
# 780000 케이스: 성공 - 18 / 실패 - 1
# 780000 케이스: 성공 - 18 / 실패 - 2
# 780000 케이스: 성공 - 19 / 실패 - 2
# 780000 케이스: 성공 - 20 / 실패 - 2
# 780000 케이스: 성공 - 21 / 실패 - 2
# 780000 케이스: 성공 - 21 / 실패 - 3
# 780000 케이스: 성공 - 22 / 실패 - 3
# 780000 케이스: 성공 - 23 / 실패 - 3
# 780000 케이스: 성공 - 24 / 실패 - 3
# 780000 케이스: 성공 - 25 / 실패 - 3
# 780000 케이스: 성공 - 26 / 실패 - 3
# 780000 케이스: 성공 - 27 / 실패 - 3
# 780000 케이스: 성공 - 28 / 실패 - 3
# 780000 케이스: 성공 - 29 / 실패 - 3
# 780000 케이스: 성공 - 30 / 실패 - 3
# 780000 케이스: 성공 - 31 / 실패 - 3
# 780000 케이스: 성공 - 32 / 실패 - 3
# 780000 케이스: 성공 - 33 / 실패 - 3
# 780000 케이스: 성공 - 34 / 실패 - 3
# 780000 케이스: 성공 - 34 / 실패 - 4
# 780000 케이스: 성공 - 35 / 실패 - 4
# 780000 케이스: 성공 - 36 / 실패 - 4
# 780000 케이스: 성공 - 37 / 실패 - 4
# 780000 케이스: 성공 - 38 / 실패 - 4
# 780000 케이스: 성공 - 39 / 실패 - 4
# 780000 케이스: 성공 - 39 / 실패 - 5
# 케이스 실패: 780000
# 790000 케이스: 성공 - 1 / 실패 - 0
# 790000 케이스: 성공 - 1 / 실패 - 1
# 790000 케이스: 성공 - 2 / 실패 - 1
# 790000 케이스: 성공 - 2 / 실패 - 2
# 790000 케이스: 성공 - 2 / 실패 - 3
# 790000 케이스: 성공 - 2 / 실패 - 4
# 790000 케이스: 성공 - 3 / 실패 - 4
# 790000 케이스: 성공 - 4 / 실패 - 4
# 790000 케이스: 성공 - 4 / 실패 - 5
# 케이스 실패: 790000
# 800000 케이스: 성공 - 0 / 실패 - 1
# 800000 케이스: 성공 - 1 / 실패 - 1
# 800000 케이스: 성공 - 1 / 실패 - 2
# 800000 케이스: 성공 - 2 / 실패 - 2
# 800000 케이스: 성공 - 2 / 실패 - 3
# 800000 케이스: 성공 - 3 / 실패 - 3
# 800000 케이스: 성공 - 3 / 실패 - 4
# 800000 케이스: 성공 - 4 / 실패 - 4
# 800000 케이스: 성공 - 5 / 실패 - 4
# 800000 케이스: 성공 - 6 / 실패 - 4
# 800000 케이스: 성공 - 7 / 실패 - 4
# 800000 케이스: 성공 - 8 / 실패 - 4
# 800000 케이스: 성공 - 9 / 실패 - 4
# 800000 케이스: 성공 - 10 / 실패 - 4
# 800000 케이스: 성공 - 11 / 실패 - 4
# 800000 케이스: 성공 - 12 / 실패 - 4
# 800000 케이스: 성공 - 13 / 실패 - 4
# 800000 케이스: 성공 - 13 / 실패 - 5
# 케이스 실패: 800000
# 810000 케이스: 성공 - 0 / 실패 - 1
# 810000 케이스: 성공 - 1 / 실패 - 1
# 810000 케이스: 성공 - 2 / 실패 - 1
# 810000 케이스: 성공 - 2 / 실패 - 2
# 810000 케이스: 성공 - 3 / 실패 - 2
# 810000 케이스: 성공 - 4 / 실패 - 2
# 810000 케이스: 성공 - 5 / 실패 - 2
# 810000 케이스: 성공 - 6 / 실패 - 2
# 810000 케이스: 성공 - 7 / 실패 - 2
# 810000 케이스: 성공 - 8 / 실패 - 2
# 810000 케이스: 성공 - 9 / 실패 - 2
# 810000 케이스: 성공 - 10 / 실패 - 2
# 810000 케이스: 성공 - 11 / 실패 - 2
# 810000 케이스: 성공 - 12 / 실패 - 2
# 810000 케이스: 성공 - 13 / 실패 - 2
# 810000 케이스: 성공 - 14 / 실패 - 2
# 810000 케이스: 성공 - 15 / 실패 - 2
# 810000 케이스: 성공 - 16 / 실패 - 2
# 810000 케이스: 성공 - 17 / 실패 - 2
# 810000 케이스: 성공 - 18 / 실패 - 2
# 810000 케이스: 성공 - 19 / 실패 - 2
# 810000 케이스: 성공 - 20 / 실패 - 2
# 810000 케이스: 성공 - 21 / 실패 - 2
# 810000 케이스: 성공 - 22 / 실패 - 2
# 810000 케이스: 성공 - 22 / 실패 - 3
# 810000 케이스: 성공 - 23 / 실패 - 3
# 810000 케이스: 성공 - 23 / 실패 - 4
# 810000 케이스: 성공 - 24 / 실패 - 4
# 810000 케이스: 성공 - 25 / 실패 - 4
# 810000 케이스: 성공 - 26 / 실패 - 4
# 810000 케이스: 성공 - 26 / 실패 - 5
# 케이스 실패: 810000
# 820000 케이스: 성공 - 1 / 실패 - 0
# 820000 케이스: 성공 - 2 / 실패 - 0
# 820000 케이스: 성공 - 3 / 실패 - 0
# 820000 케이스: 성공 - 4 / 실패 - 0
# 820000 케이스: 성공 - 5 / 실패 - 0
# 820000 케이스: 성공 - 6 / 실패 - 0
# 820000 케이스: 성공 - 7 / 실패 - 0
# 820000 케이스: 성공 - 7 / 실패 - 1
# 820000 케이스: 성공 - 8 / 실패 - 1
# 820000 케이스: 성공 - 9 / 실패 - 1
# 820000 케이스: 성공 - 10 / 실패 - 1
# 820000 케이스: 성공 - 10 / 실패 - 2
# 820000 케이스: 성공 - 11 / 실패 - 2
# 820000 케이스: 성공 - 11 / 실패 - 3
# 820000 케이스: 성공 - 12 / 실패 - 3
# 820000 케이스: 성공 - 13 / 실패 - 3
# 820000 케이스: 성공 - 14 / 실패 - 3
# 820000 케이스: 성공 - 15 / 실패 - 3
# 820000 케이스: 성공 - 16 / 실패 - 3
# 820000 케이스: 성공 - 17 / 실패 - 3
# 820000 케이스: 성공 - 18 / 실패 - 3
# 820000 케이스: 성공 - 19 / 실패 - 3
# 820000 케이스: 성공 - 20 / 실패 - 3
# 820000 케이스: 성공 - 20 / 실패 - 4
# 820000 케이스: 성공 - 21 / 실패 - 4
# 820000 케이스: 성공 - 22 / 실패 - 4
# 820000 케이스: 성공 - 23 / 실패 - 4
# 820000 케이스: 성공 - 23 / 실패 - 5
# 케이스 실패: 820000
# 830000 케이스: 성공 - 1 / 실패 - 0
# 830000 케이스: 성공 - 2 / 실패 - 0
# 830000 케이스: 성공 - 3 / 실패 - 0
# 830000 케이스: 성공 - 4 / 실패 - 0
# 830000 케이스: 성공 - 5 / 실패 - 0
# 830000 케이스: 성공 - 6 / 실패 - 0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[84], line 34
#      30         n += step
#      32     return n
# ---> 34 point = convergence_point(start=50000, step=10000, window=100, threshold=0.95)
#      35 print("수렴 케이스:", point)
#
# Cell In[84], line 13, in convergence_point(start, step, window, threshold)
#      10 fail_case_count = 0
#      12 for i in range(window):
# ---> 13     r = rain(n, plot=True, dynamic=False)
#      14     v = (4 * r[0] / r[1])
#      16     if int(v * 100) == 314:
#
# Cell In[74], line 75, in rain(number_of_drops, length_of_field, plot, format, dynamic)
#      70 # plt.savefig("Pi_estimate_for_%s_drops_thrown.pdf" % number_of_drops)
#      72 if plot and not dynamic:
#      73     # If the plot option is passed and matplotlib is installed this plots
#      74     # the final set of drops
# ---> 75     plot_rain_drops(drops_in_circle, drops_out_of_circle, length_of_field, format)
#      77 return [number_of_drops_in_circle, number_of_drops]
#
# Cell In[74], line 37, in plot_rain_drops(drops_in_circle, drops_out_of_circle, length_of_field, format)
#      35 plt.legend(loc="center")
#      36 plt.title("%s drops: %s landed in circle, estimating $\pi$ as %.4f." % (number_of_drops, number_of_drops_in_circle, 4 * number_of_drops_in_circle / number_of_drops))
# ---> 37 plt.savefig("%s_drops.%s" % (number_of_drops, format))
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/ml_2025/lib/python3.10/site-packages/matplotlib/pyplot.py:977, in savefig(*args, **kwargs)
#     974 @_copy_docstring_and_deprecators(Figure.savefig)
#     975 def savefig(*args, **kwargs):
#     976     fig = gcf()
# --> 977     res = fig.savefig(*args, **kwargs)
#     978     fig.canvas.draw_idle()   # need this if 'transparent=True' to reset colors
#     979     return res
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/ml_2025/lib/python3.10/site-packages/matplotlib/figure.py:3058, in Figure.savefig(self, fname, transparent, **kwargs)
#    3054     for ax in self.axes:
#    3055         stack.enter_context(
#    3056             ax.patch._cm_set(facecolor='none', edgecolor='none'))
# -> 3058 self.canvas.print_figure(fname, **kwargs)
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/ml_2025/lib/python3.10/site-packages/matplotlib/backend_bases.py:2319, in FigureCanvasBase.print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2315 try:
#    2316     # _get_renderer may change the figure dpi (as vector formats
#    2317     # force the figure dpi to 72), so we need to set it again here.
#    2318     with cbook._setattr_cm(self.figure, dpi=dpi):
# -> 2319         result = print_method(
#    2320             filename,
#    2321             facecolor=facecolor,
#    2322             edgecolor=edgecolor,
#    2323             orientation=orientation,
#    2324             bbox_inches_restore=_bbox_inches_restore,
#    2325             **kwargs)
#    2326 finally:
#    2327     if bbox_inches and restore_bbox:
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/ml_2025/lib/python3.10/site-packages/matplotlib/backend_bases.py:1648, in _check_savefig_extra_args.<locals>.wrapper(*args, **kwargs)
#    1640     _api.warn_deprecated(
#    1641         '3.3', name=name, removal='3.6',
#    1642         message='%(name)s() got unexpected keyword argument "'
#    1643                 + arg + '" which is no longer supported as of '
#    1644                 '%(since)s and will become an error '
#    1645                 '%(removal)s')
#    1646     kwargs.pop(arg)
# -> 1648 return func(*args, **kwargs)
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/ml_2025/lib/python3.10/site-packages/matplotlib/_api/deprecation.py:389, in delete_parameter.<locals>.wrapper(*inner_args, **inner_kwargs)
#     384 @functools.wraps(func)
#     385 def wrapper(*inner_args, **inner_kwargs):
#     386     if len(inner_args) <= name_idx and name not in inner_kwargs:
#     387         # Early return in the simple, non-deprecated case (much faster than
#     388         # calling bind()).
# --> 389         return func(*inner_args, **inner_kwargs)
#     390     arguments = signature.bind(*inner_args, **inner_kwargs).arguments
#     391     if is_varargs and arguments.get(name):
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/ml_2025/lib/python3.10/site-packages/matplotlib/backends/backend_pdf.py:2790, in FigureCanvasPdf.print_pdf(self, filename, dpi, bbox_inches_restore, metadata)
#    2785 file.newPage(width, height)
#    2786 renderer = MixedModeRenderer(
#    2787     self.figure, width, height, dpi,
#    2788     RendererPdf(file, dpi, height, width),
#    2789     bbox_inches_restore=bbox_inches_restore)
# -> 2790 self.figure.draw(renderer)
#    2791 renderer.finalize()
#    2792 if not isinstance(filename, PdfPages):
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/ml_2025/lib/python3.10/site-packages/matplotlib/artist.py:74, in _finalize_rasterization.<locals>.draw_wrapper(artist, renderer, *args, **kwargs)
#      72 @wraps(draw)
#      73 def draw_wrapper(artist, renderer, *args, **kwargs):
# ---> 74     result = draw(artist, renderer, *args, **kwargs)
#      75     if renderer._rasterizing:
#      76         renderer.stop_rasterizing()
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/ml_2025/lib/python3.10/site-packages/matplotlib/artist.py:51, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      48     if artist.get_agg_filter() is not None:
#      49         renderer.start_filter()
# ---> 51     return draw(artist, renderer)
#      52 finally:
#      53     if artist.get_agg_filter() is not None:
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/ml_2025/lib/python3.10/site-packages/matplotlib/figure.py:2845, in Figure.draw(self, renderer)
#    2842         # ValueError can occur when resizing a window.
#    2844 self.patch.draw(renderer)
# -> 2845 mimage._draw_list_compositing_images(
#    2846     renderer, self, artists, self.suppressComposite)
#    2848 for sfig in self.subfigs:
#    2849     sfig.draw(renderer)
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/ml_2025/lib/python3.10/site-packages/matplotlib/image.py:132, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     130 if not_composite or not has_images:
#     131     for a in artists:
# --> 132         a.draw(renderer)
#     133 else:
#     134     # Composite any adjacent images together
#     135     image_group = []
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/ml_2025/lib/python3.10/site-packages/matplotlib/artist.py:51, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      48     if artist.get_agg_filter() is not None:
#      49         renderer.start_filter()
# ---> 51     return draw(artist, renderer)
#      52 finally:
#      53     if artist.get_agg_filter() is not None:
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/ml_2025/lib/python3.10/site-packages/matplotlib/axes/_base.py:3091, in _AxesBase.draw(self, renderer)
#    3088         a.draw(renderer)
#    3089     renderer.stop_rasterizing()
# -> 3091 mimage._draw_list_compositing_images(
#    3092     renderer, self, artists, self.figure.suppressComposite)
#    3094 renderer.close_group('axes')
#    3095 self.stale = False
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/ml_2025/lib/python3.10/site-packages/matplotlib/image.py:132, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     130 if not_composite or not has_images:
#     131     for a in artists:
# --> 132         a.draw(renderer)
#     133 else:
#     134     # Composite any adjacent images together
#     135     image_group = []
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/ml_2025/lib/python3.10/site-packages/matplotlib/artist.py:51, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      48     if artist.get_agg_filter() is not None:
#      49         renderer.start_filter()
# ---> 51     return draw(artist, renderer)
#      52 finally:
#      53     if artist.get_agg_filter() is not None:
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/ml_2025/lib/python3.10/site-packages/matplotlib/collections.py:990, in _CollectionWithSizes.draw(self, renderer)
#     987 @artist.allow_rasterization
#     988 def draw(self, renderer):
#     989     self.set_sizes(self._sizes, self.figure.dpi)
# --> 990     super().draw(renderer)
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/ml_2025/lib/python3.10/site-packages/matplotlib/artist.py:51, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      48     if artist.get_agg_filter() is not None:
#      49         renderer.start_filter()
# ---> 51     return draw(artist, renderer)
#      52 finally:
#      53     if artist.get_agg_filter() is not None:
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/ml_2025/lib/python3.10/site-packages/matplotlib/collections.py:420, in Collection.draw(self, renderer)
#     418     gc.set_antialiased(self._antialiaseds[0])
#     419     gc.set_url(self._urls[0])
# --> 420     renderer.draw_markers(
#     421         gc, paths[0], combined_transform.frozen(),
#     422         mpath.Path(offsets), transOffset, tuple(facecolors[0]))
#     423 else:
#     424     renderer.draw_path_collection(
#     425         gc, transform.frozen(), paths,
#     426         self.get_transforms(), offsets, transOffset,
#    (...)
#     429         self._antialiaseds, self._urls,
#     430         self._offset_position)
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/ml_2025/lib/python3.10/site-packages/matplotlib/backends/backend_pdf.py:2104, in RendererPdf.draw_markers(self, gc, marker_path, marker_trans, path, trans, rgbFace)
#    2102             continue
#    2103         dx, dy = x - lastx, y - lasty
# -> 2104         output(1, 0, 0, 1, dx, dy, Op.concat_matrix,
#    2105                marker, Op.use_xobject)
#    2106         lastx, lasty = x, y
#    2107 output(Op.grestore)
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/ml_2025/lib/python3.10/site-packages/matplotlib/backends/backend_pdf.py:840, in PdfFile.output(self, *data)
#     839 def output(self, *data):
# --> 840     self.write(fill([pdfRepr(x) for x in data]))
#     841     self.write(b'\n')
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/ml_2025/lib/python3.10/site-packages/matplotlib/backends/backend_pdf.py:840, in <listcomp>(.0)
#     839 def output(self, *data):
# --> 840     self.write(fill([pdfRepr(x) for x in data]))
#     841     self.write(b'\n')
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/ml_2025/lib/python3.10/site-packages/matplotlib/backends/backend_pdf.py:255, in pdfRepr(obj)
#     252 """Map Python objects to PDF syntax."""
#     254 # Some objects defined later have their own pdfRepr method.
# --> 255 if hasattr(obj, 'pdfRepr'):
#     256     return obj.pdfRepr()
#     258 # Floats. PDF does not have exponential notation (1.0e-10) so we
#     259 # need to use %f with some precision.  Perhaps the precision
#     260 # should adapt to the magnitude of the number?
#
# KeyboardInterrupt:

# %%
import math

def convergence_point(start=10000, step=10000, window=100, threshold=0.95):
    required = int(window * threshold)  # 최소 만족 개수

    n = start

    while True:
        success_case_count = 0
        fail_case_count = 0
        
        for i in range(window):
            r = rain(n, plot=True, dynamic=False)
            v = (4 * r[0] / r[1])

            if int(v * 100) == 314:
                success_case_count += 1
            else:
                fail_case_count += 1

            print(f"{n} 케이스: 성공 - {success_case_count} / 실패 - {fail_case_count}")

            if fail_case_count > (window - window * threshold):
                print(f"케이스 실패: {n}")
                break

        if success_case_count >= window * threshold:
            break
            
        n += step
    
    return n
    
point = convergence_point(start=830000, step=10000, window=10, threshold=0.9)
print("수렴 케이스:", point)
# Out:
# 830000 케이스: 성공 - 0 / 실패 - 1
# 830000 케이스: 성공 - 1 / 실패 - 1
# 830000 케이스: 성공 - 2 / 실패 - 1
# 830000 케이스: 성공 - 3 / 실패 - 1
# 830000 케이스: 성공 - 3 / 실패 - 2
# 케이스 실패: 830000
# 840000 케이스: 성공 - 1 / 실패 - 0
# 840000 케이스: 성공 - 2 / 실패 - 0
# 840000 케이스: 성공 - 3 / 실패 - 0
# 840000 케이스: 성공 - 4 / 실패 - 0
# 840000 케이스: 성공 - 5 / 실패 - 0
# /var/folders/hz/hyh3x0dx2yz6y9glqjv9qt1m0000gn/T/ipykernel_40925/2867468761.py:62: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   plt.figure()
# 840000 케이스: 성공 - 6 / 실패 - 0
# 840000 케이스: 성공 - 7 / 실패 - 0
# 840000 케이스: 성공 - 7 / 실패 - 1
# 840000 케이스: 성공 - 7 / 실패 - 2
# 케이스 실패: 840000
# 850000 케이스: 성공 - 0 / 실패 - 1
# 850000 케이스: 성공 - 1 / 실패 - 1
# 850000 케이스: 성공 - 2 / 실패 - 1
# 850000 케이스: 성공 - 2 / 실패 - 2
# 케이스 실패: 850000
# 860000 케이스: 성공 - 1 / 실패 - 0
# 860000 케이스: 성공 - 2 / 실패 - 0
# 860000 케이스: 성공 - 3 / 실패 - 0
# 860000 케이스: 성공 - 4 / 실패 - 0
# 860000 케이스: 성공 - 5 / 실패 - 0
# 860000 케이스: 성공 - 5 / 실패 - 1
# 860000 케이스: 성공 - 6 / 실패 - 1
# 860000 케이스: 성공 - 7 / 실패 - 1
# 860000 케이스: 성공 - 8 / 실패 - 1
# 860000 케이스: 성공 - 9 / 실패 - 1
# 수렴 케이스: 860000

# %% [markdown]
# # Multivariate Gaussian Distribution
#
# 두 연속 확률변수에 대하여, 시뮬레이션된 $ (x,y)$ 값을 이용해 결합확률밀도함수(joint probability density function)를 추정하고 이를 시각화하라.
#
# ### Example. Assume  <br>
# mean of X = 1, mean of Y = 2 <br>
# variance of X = 2, variance of Y = 4 <br>
# covariance of xy and yx = 1

# %%
mu    = [1, 2]
Sigma = [[2, 1],
         [1, 4]]

X, Y = RV(MultivariateNormal(mean = mu, cov = Sigma))
Z = X + Y

# understand each output 

x = X.sim(10000)
y = Y.sim(10000)
z = Z.sim(10000)
print('X mean:', x.mean())
print('Y mean:', y.mean())
print('Z mean:', z.mean())
print('X variance:', x.sd()**2)
print('Y variance:', y.sd()**2)
print('Z variance:', z.sd()**2)
# Out:
# X mean: 0.9874801935601728
# Y mean: 2.0221246924184415
# Z mean: 2.963142844748058
# X variance: 2.0154872981849876
# Y variance: 4.0227130151776604
# Z variance: 8.245042388857753

# %%
(X & Y).sim(10000).plot(type="density")

# %% [markdown]
# ## Assignment 4
#
# 다변량 정규분포(Multivariate Gaussian)를 생성하시오.
#
# - $X$ 의 분산은 2,
# - $Y$ 의 분산은 4로 설정한다.
#
# 아래 제시된 그림과 유사한 분포를 시각화하시오.
#
# <img src="https://raw.githubusercontent.com/shiernee/Advanced_ML/main/Week2/Exercise3_Multivariate_Image.png" width="512">

# %%
''' Assignment 4 '''
mu    = [4, 2]
Sigma = [[2, -1],
         [-1, 4]]

X, Y = RV(MultivariateNormal(mean = mu, cov = Sigma))
(X & Y).sim(10000).plot(type="density")

# %% [markdown]
# # Regularization
#
# 여기서는 릿지 회귀(Ridge regression)에서 정규화 항이 과적합(overfitting)을 줄이는 데 어떻게 도움이 되는지를 살펴본다.

# %%
import numpy as np
import matplotlib.pyplot as plt

from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import Ridge
from sklearn.preprocessing import MinMaxScaler 
from sklearn.metrics import mean_squared_error as mse

# generate 1d regression data 
def make_1dregression_data(n=21):
    np.random.seed(0)
    xtrain = np.linspace(0.0, 20, n)
    xtest = np.arange(0.0, 20, 0.1)
    sigma2 = 4
    w = np.array([-1.5, 1/9.])
    fun = lambda x: w[0]*x + w[1]*np.square(x)
    ytrain = fun(xtrain) + np.random.normal(0, 1, xtrain.shape) * \
        np.sqrt(sigma2)
    ytest= fun(xtest) + np.random.normal(0, 1, xtest.shape) * \
        np.sqrt(sigma2)
    return xtrain, ytrain, xtest, ytest

# %%
import numpy as np
n=21
xtrain = np.linspace(0.0, 20, n)
w = np.array([-1.5, 1/9.])
fun = lambda x: w[0]*x + w[1]*np.square(x)

ytrain = fun(xtrain)

# %%
# split data into train and test
xtrain, ytrain, xtest, ytest = make_1dregression_data(n=21)

#Rescaling data
scaler = MinMaxScaler(feature_range=(-1, 1))
Xtrain = scaler.fit_transform(xtrain.reshape(-1, 1))
Xtest = scaler.transform(xtest.reshape(-1, 1))

# fit Ridge model with different regularizer strength
deg = 14
alphas = np.logspace(-10, 1.3, 10)  # Regularization strength
nalphas = len(alphas)
mse_train = np.empty(nalphas)
mse_test = np.empty(nalphas)
ytest_pred_stored = dict()


for i, alpha in enumerate(alphas):
    model = Ridge(alpha=alpha, fit_intercept=False)
    poly_features = PolynomialFeatures(degree=deg, include_bias=False)  # create 14 features which is used as X
    Xtrain_poly = poly_features.fit_transform(Xtrain)
    model.fit(Xtrain_poly, ytrain)
    ytrain_pred = model.predict(Xtrain_poly)
    Xtest_poly = poly_features.transform(Xtest)
    ytest_pred = model.predict(Xtest_poly)
    mse_train[i] = mse(ytrain_pred, ytrain) 
    mse_test[i] = mse(ytest_pred, ytest)
    ytest_pred_stored[alpha] = ytest_pred

# %%
# Plot MSE vs degree
fig, ax = plt.subplots()
mask = [True]*nalphas
ax.plot(alphas[mask], mse_test[mask], color = 'r', marker = 'x',label='test')
ax.plot(alphas[mask], mse_train[mask], color='b', marker = 's', label='train')
ax.set_xscale('log')
ax.legend(loc='upper right', shadow=True)
plt.xlabel('L2 regularizer')
plt.ylabel('mse')
plt.show()

# %%
# Plot fitted functions
chosen_alphas = alphas[[0,5,8]]
for i, alpha in enumerate(alphas):
    fig, ax = plt.subplots()
    ax.scatter(xtrain, ytrain)
    ax.plot(xtest, ytest_pred_stored[alpha])
    plt.title('L2 regularizer {:0.5e}'.format(alpha))
    plt.show()

# %% [markdown]
# ## Assignment 5
#
# - 모델 학습에서 **정규화 계수(regularizer strength)** 를 어떻게 선택하는 것이 최적인지 설명하시오.
#
# - 정규화 계수가 너무 작을 때와 너무 클 때 각각 모델에 어떤 영향을 주는지 비교하시오.
#
# - 최적의 정규화 계수를 찾기 위해 사용할 수 있는 방법(예: 검증 데이터셋 활용, 교차 검증 등)을 설명하시오.
#
# 아래 셀에 답변을 작성하시오.

# %%
''' Assignment 5 '''
'''
모델 학습에서 정규화 계수는 모델의 복잡도를 제어하는 요소로, 학습 데이터에 과적합/과소적합되는 것을 방지하기 위해 사용된다.
계수가 높다면 학습한 케이스에서만 성공하는 과적합 모델이 되고
계수가 낮다면 너무 일반화되어 올바르지 않은 결과가 도출되는 과소적합 모델이 되기 때문이다.
따라서 두 현상 사이의 균형을 이루는 최적의 정규화 계수를 찾아야 한다.

최적의 정규화 계수를 찾는 방법 중 하나는 검증 데이터셋을 활용하는 것이다.
학습하는 데이터셋과 검증에 사용되는 데이터를 구분하여, 데이터 셋간의 교차 검증을 통해 특정 데이터셋에 과적합 되는 것을 방지할 수 있다.
이러한 과정을 통해 오차를 비교하여 가장 성능이 좋은 정규화 계수를 찾는 것이다.

이 외에도 대표적으로 교차 검증 방법이 있다.
바로 데이터 셋을 여러 폴드로 나누어, 하나의 데이터셋 안에서 여러 검증, 학습 데이터를 만들어내는 방식이다.
검증 데이터셋 방식을 정적인 데이터 셋이지만, 교차 검증은 하나의 데이터셋을 여러개로 쪼개어 여러 케이스의 학습과 검증과정을 걷쳐 조금 더 안정화된 검증을 할 수 있도록 한다.

그렇다면 이 2가지 방식 중 교차 검증이 안정성이 높기에 모델을 학습하는데 최적의 방법으로 생각할 수 있을 것이다.
하지만, 교차 검증과 같은 방식은 검증 데이터셋에 비해 계산량이 많고, 주로 데이터 셋이 적은 상황에서 기존에 데이터를 최대한 학습/검증 데이터로 활용하기 위해 사용된다.
검증 데이터 셋은 이와 반대로 간단하고 빠르며 데이터가 많을때 원활한 처리가 가능하다.
'''
# Out:
# '\n모델 학습에서 정규화 계수는 모델의 복잡도를 제어하는 요소로, 학습 데이터에 과적합/과소적합되는 것을 방지하기 위해 사용된다.\n계수가 높다면 학습한 케이스에서만 성공하는 과적합 모델이 되고\n계수가 낮다면 너무 일반화되어 올바르지 않은 결과가 도출되는 과소적합 모델이 되기 때문이다.\n따라서 두 현상 사이의 균형을 이루는 최적의 정규화 계수를 찾아야 한다.\n\n최적의 정규화 계수를 찾는 방법 중 하나는 검증 데이터셋을 활용하는 것이다.\n학습하는 데이터셋과 검증에 사용되는 데이터를 구분하여, 데이터 셋간의 교차 검증을 통해 특정 데이터셋에 과적합 되는 것을 방지할 수 있다.\n이러한 과정을 통해 오차를 비교하여 가장 성능이 좋은 정규화 계수를 찾는 것이다.\n\n이 외에도 대표적으로 교차 검증 방법이 있다.\n바로 데이터 셋을 여러 폴드로 나누어, 하나의 데이터셋 안에서 여러 검증, 학습 데이터를 만들어내는 방식이다.\n검증 데이터셋 방식을 정적인 데이터 셋이지만, 교차 검증은 하나의 데이터셋을 여러개로 쪼개어 여러 케이스의 학습과 검증과정을 걷쳐 조금 더 안정화된 검증을 할 수 있도록 한다.\n\n그렇다면 이 2가지 방식 중 교차 검증이 안정성이 높기에 모델을 학습하는데 최적의 방법으로 생각할 수 있을 것이다.\n하지만, 교차 검증과 같은 방식은 검증 데이터셋에 비해 계산량이 많고, 주로 데이터 셋이 적은 상황에서 기존에 데이터를 최대한 학습/검증 데이터로 활용하기 위해 사용된다.\n검증 데이터 셋은 이와 반대로 간단하고 빠르며 데이터가 많을때 원활한 처리가 가능하다.\n'
